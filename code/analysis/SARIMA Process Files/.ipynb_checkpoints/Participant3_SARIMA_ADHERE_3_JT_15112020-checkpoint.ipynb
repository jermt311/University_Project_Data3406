# %% [markdown]
# Notebook done by Jeremy

# %% [markdown]
# # Imports

# %%
import pandas as pd
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline  
import statsmodels as st
import statsmodels.api as sm
from scipy import stats
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error, r2_score
from dateutil.parser import parse
import scipy.stats as scs
from pylab import rcParams
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams

#Stop warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read Data

# %%
def read_CLEAN_data(filename):
    #Read in CSV file
    dat = pd.read_csv(filename)
    #Convert datetimes
    dat["Date"] = pd.to_datetime(dat["Date"], format = '%Y-%m-%d').dt.date
    
    return dat
# 10 hours of non zeroes 
def adherence_check1(df):
  df1 = df.copy()
  df1['Not Zero'] = df1['Steps'] > 0
  df1 = df1.groupby('Date').sum()
  df1 = df1['Not Zero'] > 10 
  return df1

#Greater than 500 steps
def adherence_check2(df,min):
  df1 = df.copy()
  df1 = df1.groupby('Date').sum()
  df1 = df1['Steps']> min
  return df1 

#Active in 3 time blocks 
def adherence_check3(df):
  df1 = df.copy()
  bins = [-1,2,10,14,25,np.inf]
  names = ['3','1','2', '3', '3']
  df1['3timeblock'] = pd.cut(df1['Hour'],bins, labels = names, ordered=False)
  df1 = df1.groupby(['Date','3timeblock'], as_index=False)['Steps'].sum()
  df1['Steps within timeblock'] = df1['Steps']> 0 
  df1 = df1.groupby('Date').sum()
  df1 = df1['Steps within timeblock'] ==3 
  return df1

#Combining it all into 1 dataframe
def three_method_table(x):
  valid_1= adherence_check1(x)
  valid_2= adherence_check2(x,500)
  #valid_3= adherence_check3(x)
  #result = pd.concat([valid_1,valid_2,valid_3], axis=1, join='inner')
  result = pd.concat([valid_1,valid_2], axis=1, join='inner')
  result.reset_index(level=0, inplace=True)
  #result.columns = ["Date", "10 Hours Non Zero","Steps > 500","3 Timeblock"]
  result.columns = ["Date", "10 Hours Non Zero","Steps > 500"]
  #result['All 3 True'] = result["3 Timeblock"]*result["10 Hours Non Zero"]*result["Steps > 500"]
  result['All 3 True'] = result["10 Hours Non Zero"]*result["Steps > 500"]
  result_sum = result.sum()
  return result , result_sum

def filter_by_adherence(df, measure):
    df2 = three_method_table(df)[0]
    df3 = df.merge(df2,on ='Date')
    if(measure == 1):
        mask = (df3['10 Hours Non Zero'] == True)
    elif(measure == 2):
        mask = (df3['Steps > 500'] == True)
    elif(measure == 3):
        mask = (df3['All 3 True'] == True)
    filtered_df = df3.loc[mask].drop(['10 Hours Non Zero', 'Steps > 500', 'All 3 True'], axis=1)
    #filtered_df = filtered_df.drop('index', axis=1)
    return filtered_df

# Method 1 calculates daily steps based on all the step acitivity that is available during the day
def run_method_1(df):
    
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 2 calculates daily steps based on the 10 most active hours of the day
def run_method_2(df):
    
    df = df.sort_values(by=["Date", "Steps"], ascending=False).groupby('Date').head(10)
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 3 calculates daily steps based on a 10 hour time block during the day
def run_method_3(df, start_hour, end_hour):
    
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    mask = (df['Hour'] >= start_hour) & (df['Hour'] <= end_hour)
    df = df.loc[mask]
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

def calculate_daily_steps(file_name, filter_measure, start_time, end_time):
    
    df = read_CLEAN_data(filename)
    filtered_df = filter_by_adherence(df, filter_measure)
    
    dailysteps_method2 = run_method_2(filtered_df)
    dailysteps_method1 = run_method_1(filtered_df)
    dailysteps_method3 = run_method_3(filtered_df, start_time, end_time)
    
   
    return dailysteps_method1,dailysteps_method2,dailysteps_method3

# %%
filename = "../../../data/cleaned/Participant3.csv"

filter_measure = 3
start_time = 8
end_time = 18

ds_method1, ds_method2, ds_method3 = calculate_daily_steps(filename, filter_measure, start_time, end_time)

# %%
ds_method1.set_index('Date',inplace=True)
ds_method1.shape
# Out:
# (753, 1)

# %% [markdown]
# # Method 1

# %% [markdown]
# # Steps to take to implement (S)ARIMA

# %% [markdown]
# 1) Check for Seasonality <br />
# 2) Check for Stationarity <br />
# 3) If not Stationary perform Rolling/ Smoothing/ Shifting/ Differentiation <br />
# 4) Obtain SARIMA Parameters <br />
# 5) Data Splitting and Model evaluation by plots <br />
# 6) Data Forecasting

# %% [markdown]
# ### 1) Check For Seasonality

# %% [markdown]
# ##### Simple Plot

# %%
ds_method1.plot(figsize=(19, 4))
plt.ylabel("Nubmer of Steps")
plt.show()

# %% [markdown]
# #### Seasonal Decompose Plot

# %% [markdown]
# Using the command, we can decompose the time series into three distinct components: Trend, Seasonality and noise

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method1, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# After adherence, it appears that the data does have some form of Seasonality over the years besides certain year-gaps. As such, we will employ the SARIMA here instead of ARMIA

# %% [markdown]
# # Check for data Stationarity

# %% [markdown]
# Will use this function to test for stationarity by using the **Augmented Dickey-Fuller test**

# %% [markdown]
# where <br />
# $H_0$: If failed to be rejected, time series data is not stationary <br />
# $H_1$: If $H_0$ is rejected, it means the time series data is stationary

# %%
def test_stationarity(timeseries):
    
    #Determine rolling statistics
    movingAverage = timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()
    
    #Plot rolling statistics
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.xlabel("Date")
    plt.ylabel("Number of Steps")
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    
    #Perform Dickey–Fuller test:
    print('Results of Dickey Fuller Test:')
    dftest = adfuller(timeseries['Steps'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(ds_method1)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic            -6.640681e+00
# p-value                        5.419823e-09
# #Lags Used                     6.000000e+00
# Number of Observations Used    7.460000e+02
# Critical Value (1%)           -3.439146e+00
# Critical Value (5%)           -2.865422e+00
# Critical Value (10%)          -2.568837e+00
# dtype: float64

# %% [markdown]
# For this, we will use the $\alpha$ value of 0.05 to check against the p-value of 5.419823e-09 to decide if we will accept or reject the $H_0$. As $\alpha$ > p-value, we can conclude that the data is stationary.

# %% [markdown]
# ## Making Data Stationary

# %% [markdown]
# As the data is stationary, we do not need to perform any transformation of the data to achieve stationarity.

# %% [markdown]
# ### Data Transformation to acheive Normality

# %% [markdown]
# #### Log Transformation

# %%
#Estimating trend
#ds_method1 = np.log(ds_method1)
#plt.plot(ds_method1)

# %% [markdown]
# # (S)ARIMA Parameters

# %% [markdown]
# #### ACF and PACF plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method1, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method1, ax=ax[1])
plt.show()

# %% [markdown]
# ### Parameter Selection

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(ds_method1, start_p=0, start_q=0,
                           max_p=6, max_q=6, m=12,
                           start_P=0,start_Q=0, seasonal=True,
                           d=0, D=0, max_P = 10, max_Q = 10, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=14776.320, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=14694.585, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=14719.863, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=15761.111, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=14692.627, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=14694.586, Time=0.10 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=14696.581, Time=0.42 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=14671.952, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=14673.830, Time=0.26 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=14673.808, Time=0.13 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=14675.808, Time=0.50 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=14669.738, Time=0.07 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=14671.392, Time=0.41 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=14671.364, Time=0.17 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=14667.805, Time=0.09 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=14669.457, Time=0.47 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=14669.424, Time=0.20 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=14671.424, Time=0.75 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=14663.710, Time=0.11 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=14664.545, Time=0.61 sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : AIC=14664.493, Time=0.23 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=14666.485, Time=1.00 sec
#  ARIMA(6,0,0)(0,0,0)[12] intercept   : AIC=14661.443, Time=0.14 sec
#  ARIMA(6,0,0)(1,0,0)[12] intercept   : AIC=14661.865, Time=0.76 sec
#  ARIMA(6,0,0)(0,0,1)[12] intercept   : AIC=14661.778, Time=0.26 sec
#  ARIMA(6,0,0)(1,0,1)[12] intercept   : AIC=14663.775, Time=0.94 sec
#  ARIMA(6,0,1)(0,0,0)[12] intercept   : AIC=14663.283, Time=0.22 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : AIC=14665.353, Time=0.22 sec
#  ARIMA(6,0,0)(0,0,0)[12]             : AIC=14707.230, Time=0.13 sec
#
# Best model:  ARIMA(6,0,0)(0,0,0)[12] intercept
# Total fit time: 10.016 seconds
# 14661.443216461153

# %% [markdown]
# So, the best set of paramters to select is  **ARIMA(6,0,0)(0,0,0)[12]** I selected m = 12 to represent the yearly number of months each 'season' runs for

# %%
model = sm.tsa.statespace.SARIMAX(ds_method1, order=(6,0,0), seasonal_order = (0,0,0,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.756459
#          Iterations: 1
#          Function evaluations: 85

# %%
train = ds_method1.loc['2017-08-01':'2020-01-03']
test = ds_method1.loc['2020-01-08':]
stepwise_model.fit(train)
# Out:
# ARIMA(order=(6, 0, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method1,
                                order=(6, 0, 0),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                  753
# Model:               SARIMAX(6, 0, 0)   Log Likelihood               -7285.532
# Date:                Sun, 15 Nov 2020   AIC                          14585.064
# Time:                        00:48:41   BIC                          14617.377
# Sample:                             0   HQIC                         14597.517
#                                 - 753
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3077      0.035      8.669      0.000       0.238       0.377
# ar.L2          0.1913      0.037      5.210      0.000       0.119       0.263
# ar.L3          0.0902      0.039      2.287      0.022       0.013       0.167
# ar.L4          0.0853      0.038      2.255      0.024       0.011       0.159
# ar.L5          0.1314      0.039      3.353      0.001       0.055       0.208
# ar.L6          0.1437      0.036      4.042      0.000       0.074       0.213
# sigma2      1.733e+07    1.8e-10   9.63e+16      0.000    1.73e+07    1.73e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.41   Jarque-Bera (JB):                93.90
# Prob(Q):                              0.52   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.32   Skew:                             0.69
# Prob(H) (two-sided):                  0.03   Kurtosis:                         4.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.99e+32. Standard errors may be unstable.

# %% [markdown]
# ### Some Plots

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %% [markdown]
# ### (S)ARIMA Model Validation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# Train Set 80%, Validation 20%

# %%
# the 20% point test data is on the specified date below
split_date = '2020-01-03'
data = ds_method1['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(6, 0, 0),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae1 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse1 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse1 = math.sqrt(mse1)
print(f'Mean Squared Error: {mse1.round(4)}')
print(f'Root Mean Squared Error: {round(rmse1,4)}')
print(f'Mean Absolute Error: {mae1.round(4)}')
# Out:
# Mean Squared Error: 38310636.7898
# Root Mean Squared Error: 6189.5587
# Mean Absolute Error: 4243.2207

# %% [markdown]
# ### Model Prediction

# %%
pred = results.get_prediction(start=pd.to_datetime('2020-01-03'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method1['2017':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %% [markdown]
# # Method 2

# %%
#method_1.set_index('Date',inplace=True)
ds_method2.set_index('Date',inplace=True)
ds_method2.head()
# Out:
#                    Steps
# Date
# 2017-08-01  12335.158512
# 2017-08-02   3063.008540
# 2017-08-03   7027.358587
# 2017-08-04  11413.129441
# 2017-08-05  13821.415285

# %%
ds_method2.plot(figsize=(19, 4))
plt.ylabel("Nubmer of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method2, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
test_stationarity(ds_method2)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic              -5.427954
# p-value                          0.000003
# #Lags Used                       9.000000
# Number of Observations Used    743.000000
# Critical Value (1%)             -3.439182
# Critical Value (5%)             -2.865438
# Critical Value (10%)            -2.568846
# dtype: float64

# %% [markdown]
# Again, data appears to be stationary so no transformation of the data was required.

# %%
#Estimating trend
#ds_method2 = np.log(ds_method2)
#plt.plot(ds_method2)

# %% [markdown]
# ### PACF and ACF plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method2, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method2,ax=ax[1])
plt.show()

# %% [markdown]
# ### Parameter Selection

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(ds_method2, start_p=0, start_q=0,
                           max_p=6, max_q=6, m=12,
                           start_P=0,start_Q=0, seasonal=True,
                           d=0, D=0, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=14722.987, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=14638.612, Time=0.25 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=14664.504, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=15723.205, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=14636.768, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=14638.603, Time=0.10 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=14615.844, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=14617.797, Time=0.27 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=14617.785, Time=0.15 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=14619.784, Time=0.51 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=14613.357, Time=0.08 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=14615.142, Time=0.32 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=14615.123, Time=0.16 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=14617.122, Time=1.10 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=14611.088, Time=0.10 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=14612.866, Time=0.48 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=14612.843, Time=0.18 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=14614.843, Time=0.76 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=14606.052, Time=0.11 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=14607.075, Time=0.61 sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : AIC=14607.040, Time=0.25 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=14609.031, Time=1.09 sec
#  ARIMA(6,0,0)(0,0,0)[12] intercept   : AIC=14604.169, Time=0.14 sec
#  ARIMA(6,0,0)(1,0,0)[12] intercept   : AIC=14604.840, Time=0.74 sec
#  ARIMA(6,0,0)(0,0,1)[12] intercept   : AIC=14604.779, Time=0.25 sec
#  ARIMA(6,0,0)(1,0,1)[12] intercept   : AIC=14606.775, Time=0.97 sec
#  ARIMA(6,0,1)(0,0,0)[12] intercept   : AIC=14605.993, Time=0.22 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : AIC=14607.674, Time=0.22 sec
#  ARIMA(6,0,0)(0,0,0)[12]             : AIC=14649.246, Time=0.13 sec
#
# Best model:  ARIMA(6,0,0)(0,0,0)[12] intercept
# Total fit time: 10.166 seconds
# 14604.169350159647

# %%
model = sm.tsa.statespace.SARIMAX(ds_method2, order=(6,0,0), seasonal_order = (0,0,0,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res,  ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res,  ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.717957
#          Iterations: 1
#          Function evaluations: 83

# %%
train = ds_method2.loc['2017-08-01':'2020-01-03']
test = ds_method2.loc['2020-01-08':]
stepwise_model.fit(train)
# Out:
# ARIMA(order=(6, 0, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method2,
                                order=(6,0,0),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                  753
# Model:               SARIMAX(6, 0, 0)   Log Likelihood               -7256.649
# Date:                Sun, 15 Nov 2020   AIC                          14527.298
# Time:                        00:50:41   BIC                          14559.611
# Sample:                             0   HQIC                         14539.751
#                                 - 753
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3082      0.035      8.719      0.000       0.239       0.377
# ar.L2          0.1894      0.038      5.028      0.000       0.116       0.263
# ar.L3          0.0903      0.039      2.327      0.020       0.014       0.166
# ar.L4          0.0862      0.039      2.227      0.026       0.010       0.162
# ar.L5          0.1381      0.040      3.487      0.000       0.060       0.216
# ar.L6          0.1389      0.036      3.850      0.000       0.068       0.210
# sigma2      1.604e+07    1.5e-10   1.07e+17      0.000     1.6e+07     1.6e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.40   Jarque-Bera (JB):                67.72
# Prob(Q):                              0.53   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.36   Skew:                             0.62
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.72e+32. Standard errors may be unstable.

# %% [markdown]
# ### Some Plots

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %% [markdown]
# ### Model Validation

# %%
# the 20% point test data is on the specified date below
split_date = '2020-01-03'
data = ds_method2['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(6,0, 0),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae2 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse2 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse2 = math.sqrt(mse2)
print(f'Mean Squared Error: {mse2.round(4)}')
print(f'Root Mean Squared Error: {round(rmse2,4)}')
print(f'Mean Absolute Error: {mae2.round(4)}')
# Out:
# Mean Squared Error: 35888461.6639
# Root Mean Squared Error: 5990.6979
# Mean Absolute Error: 4145.9354

# %% [markdown]
# ### Model Prediction

# %%
pred = results.get_prediction(start=pd.to_datetime('2020-01-03'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method2['2017':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Visitors')
plt.legend()
plt.show()

# %% [markdown]
# # Method 3

# %%
#method_1.set_index('Date',inplace=True)
ds_method3.set_index('Date',inplace=True)

# %%
ds_method3.plot(figsize=(19, 4))
plt.ylabel("Nubmer of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method3, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
test_stationarity(ds_method3)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic            -6.887412e+00
# p-value                        1.383186e-09
# #Lags Used                     6.000000e+00
# Number of Observations Used    7.460000e+02
# Critical Value (1%)           -3.439146e+00
# Critical Value (5%)           -2.865422e+00
# Critical Value (10%)          -2.568837e+00
# dtype: float64

# %%
#Estimating trend
#ds_method3 = np.log(ds_method3)
#plt.plot(ds_method3)

# %% [markdown]
# ### ACF and PACF plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method3,  ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method3,  ax=ax[1])
plt.show()

# %% [markdown]
# ### Parameter Selection

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(ds_method3, start_p=0, start_q=0,
                           max_p=4, max_q=10, m=12,
                           start_P=0,start_Q=0, seasonal=True,
                           d=0, D=0, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=14433.159, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=14395.592, Time=0.22 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=14405.588, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=15223.903, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=14393.652, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=14395.577, Time=0.11 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=14380.245, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=14382.235, Time=0.24 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=14382.238, Time=0.15 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.85 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=14377.754, Time=0.07 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=14379.651, Time=0.33 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=14379.665, Time=0.18 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=14381.651, Time=0.65 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=14373.661, Time=0.08 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=14375.566, Time=0.43 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=14375.574, Time=0.22 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=14377.566, Time=0.77 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=14375.511, Time=0.13 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=14379.637, Time=0.13 sec
#  ARIMA(4,0,0)(0,0,0)[12]             : AIC=14451.720, Time=0.06 sec
#
# Best model:  ARIMA(4,0,0)(0,0,0)[12] intercept
# Total fit time: 5.860 seconds
# 14373.660877824741

# %%
model = sm.tsa.statespace.SARIMAX(ds_method3, order=(4,0,0), seasonal_order = (1,0,1,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, lags=30, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=30, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.566879
#          Iterations: 5
#          Function evaluations: 421

# %%
train = ds_method3.loc['2017-08-01':'2020-01-03']
test = ds_method3.loc['2020-01-08':]
stepwise_model.fit(train)
# Out:
# ARIMA(order=(4, 0, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method3,
                                order=(4,0,0),
                                seasonal_order=(1, 0, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                Steps   No. Observations:                  753
# Model:             SARIMAX(4, 0, 0)x(1, 0, [1], 12)   Log Likelihood               -7049.168
# Date:                              Sun, 15 Nov 2020   AIC                          14112.335
# Time:                                      00:52:22   BIC                          14144.553
# Sample:                                           0   HQIC                         14124.760
#                                               - 753
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2018      0.038      5.311      0.000       0.127       0.276
# ar.L2          0.1449      0.037      3.892      0.000       0.072       0.218
# ar.L3          0.0820      0.039      2.108      0.035       0.006       0.158
# ar.L4          0.1214      0.039      3.103      0.002       0.045       0.198
# ar.S.L12       1.0014      0.005    189.197      0.000       0.991       1.012
# ma.S.L12      -0.9615      0.026    -37.187      0.000      -1.012      -0.911
# sigma2      1.251e+07   3.98e-10   3.14e+16      0.000    1.25e+07    1.25e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.32   Jarque-Bera (JB):                99.02
# Prob(Q):                              0.57   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.42   Skew:                             0.80
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.04e+32. Standard errors may be unstable.

# %% [markdown]
# ### Some Plots

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %% [markdown]
# ### Model Validation

# %%
# the 20% point test data is on the specified date below
split_date = '2020-01-03'
data = ds_method3['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(4,0,0),
                                seasonal_order=(1, 0, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae3 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse3 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse3 = math.sqrt(mse3)
print(f'Mean Squared Error: {mse3.round(4)}')
print(f'Root Mean Squared Error: {round(rmse3,4)}')
print(f'Mean Absolute Error: {mae3.round(4)}')
# Out:
# Mean Squared Error: 21555536.8855
# Root Mean Squared Error: 4642.7941
# Mean Absolute Error: 4034.4669

# %% [markdown]
# ### Prediction

# %%
pred = results.get_prediction(start=pd.to_datetime('2020-01-18'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method3['2017':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Visitors')
plt.legend()
plt.show()

# %%
models = pd.DataFrame({
    'Method': ['Method 1', 'Method 2', 'Method 3'],
    'MSE': [round(mse1, 4), round(mse2, 4), round(mse3,4)],
    'RMSE': [round(rmse1,4 ), round(rmse2, 4), round(rmse3,4)],
    'MAE': [round(mae1, 4), round(mae2, 4), round(mae3,4)]})
models
# Out:
#      Method           MSE       RMSE        MAE
# 0  Method 1  3.831064e+07  6189.5587  4243.2207
# 1  Method 2  3.588846e+07  5990.6979  4145.9354
# 2  Method 3  2.155554e+07  4642.7941  4034.4669

# %% [markdown]
# it is hard to select which of the three models had the best predicted value as they all had their strengths and weaknesses at different points of the prediction. So, i will base the best performing model off its RMSE. So, the best method is **Method 3**.
