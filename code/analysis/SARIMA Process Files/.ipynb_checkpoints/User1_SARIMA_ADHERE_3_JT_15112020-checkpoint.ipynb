# %% [markdown]
# # Imports

# %%
import pandas as pd
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline  
import statsmodels as st
import statsmodels.api as sm
from scipy import stats
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error, r2_score
from dateutil.parser import parse
import scipy.stats as scs
from pylab import rcParams
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams

#Stop warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read Data

# %%
def read_CLEAN_data(filename):
    #Read in CSV file
    dat = pd.read_csv(filename)
    #Convert datetimes
    dat["Date"] = pd.to_datetime(dat["Date"], format = '%Y-%m-%d').dt.date
    
    return dat
# 10 hours of non zeroes 
def adherence_check1(df):
  df1 = df.copy()
  df1['Not Zero'] = df1['Steps'] > 0
  df1 = df1.groupby('Date').sum()
  df1 = df1['Not Zero'] > 10 
  return df1

#Greater than 500 steps
def adherence_check2(df,min):
  df1 = df.copy()
  df1 = df1.groupby('Date').sum()
  df1 = df1['Steps']> min
  return df1 

#Active in 3 time blocks 
def adherence_check3(df):
  df1 = df.copy()
  bins = [-1,2,10,14,25,np.inf]
  names = ['3','1','2', '3', '3']
  df1['3timeblock'] = pd.cut(df1['Hour'],bins, labels = names, ordered=False)
  df1 = df1.groupby(['Date','3timeblock'], as_index=False)['Steps'].sum()
  df1['Steps within timeblock'] = df1['Steps']> 0 
  df1 = df1.groupby('Date').sum()
  df1 = df1['Steps within timeblock'] ==3 
  return df1

#Combining it all into 1 dataframe
def three_method_table(x):
  valid_1= adherence_check1(x)
  valid_2= adherence_check2(x,500)
  #valid_3= adherence_check3(x)
  #result = pd.concat([valid_1,valid_2,valid_3], axis=1, join='inner')
  result = pd.concat([valid_1,valid_2], axis=1, join='inner')
  result.reset_index(level=0, inplace=True)
  #result.columns = ["Date", "10 Hours Non Zero","Steps > 500","3 Timeblock"]
  result.columns = ["Date", "10 Hours Non Zero","Steps > 500"]
  #result['All 3 True'] = result["3 Timeblock"]*result["10 Hours Non Zero"]*result["Steps > 500"]
  result['All 3 True'] = result["10 Hours Non Zero"]*result["Steps > 500"]
  result_sum = result.sum()
  return result , result_sum

def filter_by_adherence(df, measure):
    df2 = three_method_table(df)[0]
    df3 = df.merge(df2,on ='Date')
    if(measure == 1):
        mask = (df3['10 Hours Non Zero'] == True)
    elif(measure == 2):
        mask = (df3['Steps > 500'] == True)
    elif(measure == 3):
        mask = (df3['All 3 True'] == True)
    filtered_df = df3.loc[mask].drop(['10 Hours Non Zero', 'Steps > 500', 'All 3 True'], axis=1)
    #filtered_df = filtered_df.drop('index', axis=1)
    return filtered_df

# Method 1 calculates daily steps based on all the step acitivity that is available during the day
def run_method_1(df):
    
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 2 calculates daily steps based on the 10 most active hours of the day
def run_method_2(df):
    
    df = df.sort_values(by=["Date", "Steps"], ascending=False).groupby('Date').head(10)
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 3 calculates daily steps based on a 10 hour time block during the day
def run_method_3(df, start_hour, end_hour):
    
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    mask = (df['Hour'] >= start_hour) & (df['Hour'] <= end_hour)
    df = df.loc[mask]
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

def calculate_daily_steps(file_name, filter_measure, start_time, end_time):
    
    df = read_CLEAN_data(filename)
    filtered_df = filter_by_adherence(df, filter_measure)
    
    dailysteps_method2 = run_method_2(filtered_df)
    dailysteps_method1 = run_method_1(filtered_df)
    dailysteps_method3 = run_method_3(filtered_df, start_time, end_time)
    
   
    return dailysteps_method1,dailysteps_method2,dailysteps_method3

# %%
filename = "../../../data/cleaned/User1.csv"

filter_measure = 3
start_time = 8
end_time = 18

ds_method1, ds_method2, ds_method3 = calculate_daily_steps(filename, filter_measure, start_time, end_time)

# %%
ds_method1.set_index('Date',inplace=True)
ds_method1.shape
# Out:
# (458, 1)

# %% [markdown]
# # Method 1

# %% [markdown]
# # Steps to take to implement (S)ARIMA

# %% [markdown]
# 1) Check for Seasonality <br />
# 2) Check for Stationarity <br />
# 3) If not Stationary perform Rolling/ Smoothing/ Shifting/ Differentiation <br />
# 4) Obtain SARIMA Parameters <br />
# 5) Data Splitting and Model evaluation by plots <br />
# 6) Data Forecasting

# %% [markdown]
# ### 1) Check For Seasonality

# %% [markdown]
# ##### Simple Plot

# %%
ds_method1.plot(figsize=(19, 4))
plt.ylabel("Nubmer of Steps")
plt.show()

# %% [markdown]
# #### Seasonal Decompose Plot

# %% [markdown]
# Using the command, we can decompose the time series into three distinct components: Trend, Seasonality and noise

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method1, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# After adherence, it appears that the data does not have much seasonality anymore. We can observe however, that there is a slight trend every 3 years that the user walks more during that year

# %% [markdown]
# # Check for data Stationarity

# %% [markdown]
# Will use this function to test for stationarity by using the **Augmented Dickey-Fuller test**

# %% [markdown]
# where <br />
# $H_0$: If failed to be rejected, time series data is not stationary <br />
# $H_1$: If $H_0$ is rejected, it means the time series data is stationary

# %%
def test_stationarity(timeseries):
    
    #Determine rolling statistics
    movingAverage = timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()
    
    #Plot rolling statistics
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.xlabel("Date")
    plt.ylabel("Number of Steps")
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    
    #Perform Dickey–Fuller test:
    print('Results of Dickey Fuller Test:')
    dftest = adfuller(timeseries['Steps'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(ds_method1)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic            -7.773671e+00
# p-value                        8.784394e-12
# #Lags Used                     3.000000e+00
# Number of Observations Used    4.540000e+02
# Critical Value (1%)           -3.444836e+00
# Critical Value (5%)           -2.867927e+00
# Critical Value (10%)          -2.570172e+00
# dtype: float64

# %% [markdown]
# For this, we will use the $\alpha$ value of 0.05 to check against the p-value of 8.784394e-12 to decide if we will accept or reject the $H_0$. As $\alpha$ > p-value, we can conclude that the data is stationary.

# %% [markdown]
# ## Making Data Stationary

# %% [markdown]
# As the data is stationary, we do not need to perform any transformation of the data to achieve stationarity.

# %% [markdown]
# ### Data Transformation to acheive Normality

# %% [markdown]
# #### Log Transformation

# %%
#Estimating trend
#ds_method1 = np.log(ds_method1)
#plt.plot(ds_method1)

# %% [markdown]
# # (S)ARIMA Parameters

# %% [markdown]
# #### ACF and PACF plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method1, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method1, ax=ax[1])
plt.show()

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(ds_method1, start_p=1, start_q=1,
                           max_p=4, max_q=4, m=0,
                            seasonal=False,
                           d=0 , trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=8908.123, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=9705.850, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=9052.570, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=9486.005, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=8896.712, Time=0.33 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=8983.655, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.33 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=8900.355, Time=0.22 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=8961.735, Time=0.06 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.44 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=8887.076, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=8887.564, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=8885.252, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=8889.098, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=8886.487, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=8888.466, Time=0.10 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 2.256 seconds
# 8885.252231413298

# %% [markdown]
# So, the best set of paramters to select is  **ARIMA(3,0,1)(0,0,0)[0]** I selected m = 12 to represent the yearly number of months each 'season' runs for. This might differ from the model reccomended by auto arima but the model reccomended produced PACF and ACF graphs that had autocorrelation observed. So i had to manually adjust the model parameters

# %%
model = sm.tsa.statespace.SARIMAX(ds_method1, order=(3,0,1), seasonal_order = (0,0,0,0)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.700959
#          Iterations: 8
#          Function evaluations: 494

# %% [markdown]
# No Autocorrelation observed

# %%
train = ds_method1.loc['2014-12-08':'2019-02-18']
test = ds_method1.loc['2019-02-19':]
stepwise_model.fit(train)
# Out:
# ARIMA(order=(2, 0, 0), scoring_args={}, suppress_warnings=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method1,
                                order=(3,0,1),
                                seasonal_order=(0, 0, 0, 0),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                  458
# Model:               SARIMAX(3, 0, 1)   Log Likelihood               -4415.089
# Date:                Sun, 15 Nov 2020   AIC                           8840.178
# Time:                        01:15:20   BIC                           8860.779
# Sample:                             0   HQIC                          8848.294
#                                 - 458
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2538      0.048     26.110      0.000       1.160       1.348
# ar.L2         -0.1610      0.080     -2.009      0.045      -0.318      -0.004
# ar.L3         -0.0929      0.051     -1.809      0.070      -0.194       0.008
# ma.L1         -0.9778      0.014    -69.930      0.000      -1.005      -0.950
# sigma2      1.816e+07   3.38e-10   5.38e+16      0.000    1.82e+07    1.82e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               274.24
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.95   Skew:                             1.25
# Prob(H) (two-sided):                  0.75   Kurtosis:                         5.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.94e+32. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %% [markdown]
# ### (S)ARIMA Model Validation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# Train Set 80%, Validation 20%

# %%
# the 20% point test data is on the specified date below
split_date = '2019-02-18'
data = ds_method1['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(3, 0, 1),
                                seasonal_order=(0, 0, 0, 0),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae1 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse1 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse1 = math.sqrt(mse1)
print(f'Mean Squared Error: {mse1.round(4)}')
print(f'Root Mean Squared Error: {round(rmse1,4)}')
print(f'Mean Absolute Error: {mae1.round(4)}')
# Out:
# Mean Squared Error: 22291754.8135
# Root Mean Squared Error: 4721.4145
# Mean Absolute Error: 3469.7584

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-02-18'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method1['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %% [markdown]
# # Method 2

# %%
#method_1.set_index('Date',inplace=True)
ds_method2.set_index('Date',inplace=True)
ds_method2.head()
# Out:
#                   Steps
# Date
# 2014-12-08  6550.000000
# 2014-12-12  5886.460839
# 2014-12-17  6999.000000
# 2014-12-25  7122.000000
# 2015-01-05  7836.000000

# %%
ds_method2.plot(figsize=(19, 4))
plt.ylabel("Nubmer of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method2, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
test_stationarity(ds_method2)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic            -5.944191e+00
# p-value                        2.224202e-07
# #Lags Used                     4.000000e+00
# Number of Observations Used    4.530000e+02
# Critical Value (1%)           -3.444868e+00
# Critical Value (5%)           -2.867941e+00
# Critical Value (10%)          -2.570180e+00
# dtype: float64

# %% [markdown]
# Again, data appears to be stationary so no transformation of the data was required. However, the data was not normal based on William's Observation. To normalise it, we logged the values

# %%
#Estimating trend
#ds_method2 = np.log(ds_method2)
#plt.plot(ds_method2)

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method2, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method2,ax=ax[1])
plt.show()

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(ds_method2, start_p=0, start_q=0,
                           max_p=4, max_q=4, m=12,
                            seasonal=False,
                           d=0,  trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=9645.126, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=9017.711, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=9430.148, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=8948.440, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=8928.722, Time=0.04 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=8903.390, Time=0.05 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=8875.941, Time=0.18 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=8876.648, Time=0.13 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=8876.527, Time=0.32 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.37 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=8866.470, Time=0.11 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=8873.776, Time=0.09 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=8864.746, Time=0.07 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=8872.033, Time=0.04 sec
#
# Best model:  ARIMA(4,0,0)(0,0,0)[0] intercept
# Total fit time: 1.487 seconds
# 8864.746278922981

# %%
model = sm.tsa.statespace.SARIMAX(ds_method2, order=(4,0,0), seasonal_order = (0,0,0,0)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res,  ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res,  ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.708928
#          Iterations: 1
#          Function evaluations: 61

# %%
train = ds_method2.loc['2014-12-08':'2019-02-18']
test = ds_method2.loc['2019-02-19':]
stepwise_model.fit(train)
# Out:
# ARIMA(order=(4, 0, 0), scoring_args={}, suppress_warnings=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method2,
                                order=(4, 0, 0),
                                seasonal_order=(0, 0, 0, 0),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                  458
# Model:               SARIMAX(4, 0, 0)   Log Likelihood               -4408.474
# Date:                Sun, 15 Nov 2020   AIC                           8826.948
# Time:                        01:16:11   BIC                           8847.539
# Sample:                             0   HQIC                          8835.061
#                                 - 458
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4019      0.040     10.021      0.000       0.323       0.480
# ar.L2          0.2004      0.043      4.643      0.000       0.116       0.285
# ar.L3          0.1066      0.047      2.276      0.023       0.015       0.198
# ar.L4          0.2424      0.042      5.785      0.000       0.160       0.325
# sigma2      1.591e+07   4.77e-10   3.33e+16      0.000    1.59e+07    1.59e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.91   Jarque-Bera (JB):               132.71
# Prob(Q):                              0.34   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.90   Skew:                             0.92
# Prob(H) (two-sided):                  0.51   Kurtosis:                         4.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.11e+32. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# the 20% point test data is on the specified date below
split_date = '2019-02-18'
data = ds_method2['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(4,0, 0),
                                seasonal_order=(0, 0, 0, 0),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae2 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse2 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse2 = math.sqrt(mse2)
print(f'Mean Squared Error: {mse2.round(4)}')
print(f'Root Mean Squared Error: {round(rmse2,4)}')
print(f'Mean Absolute Error: {mae2.round(4)}')
# Out:
# Mean Squared Error: 51035412.2782
# Root Mean Squared Error: 7143.9074
# Mean Absolute Error: 5977.8387

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-02-18'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method2['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %% [markdown]
# # Method 3

# %%
#method_1.set_index('Date',inplace=True)
ds_method3.set_index('Date',inplace=True)

# %%
ds_method3.plot(figsize=(19, 4))
plt.ylabel("Nubmer of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method3, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
test_stationarity(ds_method3)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic              -3.593706
# p-value                          0.005882
# #Lags Used                       8.000000
# Number of Observations Used    449.000000
# Critical Value (1%)             -3.444998
# Critical Value (5%)             -2.867999
# Critical Value (10%)            -2.570210
# dtype: float64

# %%
#Estimating trend
#ds_method3 = np.log(ds_method3)
#plt.plot(ds_method3)

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method3, lags=30, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method3, lags=30, ax=ax[1])
plt.show()

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(ds_method3, start_p=0, start_q=0,
                           max_p=4, max_q=4, m=12,
                            seasonal=False,
                           d=0,  trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=9435.934, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=8835.162, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=9222.281, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=8771.442, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=8748.264, Time=0.04 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=8724.889, Time=0.05 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=8685.515, Time=0.18 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=8686.980, Time=0.11 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=8686.705, Time=0.16 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=8684.491, Time=0.13 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=8683.104, Time=0.13 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=8680.387, Time=0.14 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=9026.553, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=8687.996, Time=0.14 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=8681.826, Time=0.15 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=9138.461, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=8679.625, Time=0.23 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=8698.681, Time=0.06 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0]
# Total fit time: 1.762 seconds
# 8679.624857884995

# %%
model = sm.tsa.statespace.SARIMAX(ds_method3, order=(2,0,1), seasonal_order = (0,0,0,0)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, lags=30, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=30, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.466840
#          Iterations: 4
#          Function evaluations: 191

# %%
train = ds_method3.loc['2014-12-08':'2019-02-18']
test = ds_method3.loc['2019-02-19':]
stepwise_model.fit(train)
# Out:
# ARIMA(order=(2, 0, 1), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method3,
                                order=(2,0,1),
                                seasonal_order=(0, 0, 0, 0),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                  458
# Model:               SARIMAX(2, 0, 1)   Log Likelihood               -4318.729
# Date:                Sun, 15 Nov 2020   AIC                           8645.459
# Time:                        01:16:45   BIC                           8661.949
# Sample:                             0   HQIC                          8651.955
#                                 - 458
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1749      0.061     19.318      0.000       1.056       1.294
# ar.L2         -0.1768      0.060     -2.923      0.003      -0.295      -0.058
# ma.L1         -0.8950      0.032    -28.297      0.000      -0.957      -0.833
# sigma2      1.139e+07   1.76e-10   6.48e+16      0.000    1.14e+07    1.14e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               118.08
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.17   Skew:                             0.89
# Prob(H) (two-sided):                  0.34   Kurtosis:                         4.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.05e+33. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# the 20% point test data is on the specified date below
split_date = '2019-02-18'
data = ds_method3['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(2,0,1),
                                seasonal_order=(0,0,0,0),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae3 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse3 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse3 = math.sqrt(mse3)
print(f'Mean Squared Error: {mse3.round(4)}')
print(f'Root Mean Squared Error: {round(rmse3,4)}')
print(f'Mean Absolute Error: {mae3.round(4)}')
# Out:
# Mean Squared Error: 14495826.7591
# Root Mean Squared Error: 3807.3385
# Mean Absolute Error: 2942.4607

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-02-18'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method3['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Visitors')
plt.legend()
plt.show()

# %%
models = pd.DataFrame({
    'Method': ['Method 1', 'Method 2', 'Method 3'],
    'MSE': [round(mse1, 4), round(mse2, 4), round(mse3,4)],
    'RMSE': [round(rmse1,4 ), round(rmse2, 4), round(rmse3,4)],
    'MAE': [round(mae1, 4), round(mae2, 4), round(mae3,4)]})
models
# Out:
#      Method           MSE       RMSE        MAE
# 0  Method 1  2.229175e+07  4721.4145  3469.7584
# 1  Method 2  5.103541e+07  7143.9074  5977.8387
# 2  Method 3  1.449583e+07  3807.3385  2942.4607

# %% [markdown]
# Based on the above predictions, we can observe that **Model 2** has the best prediction with **Method 1** performing the worst. However, the **RMSE** value of **Model 2** the highest among the three. But i would say that Model 2 performs the best here
