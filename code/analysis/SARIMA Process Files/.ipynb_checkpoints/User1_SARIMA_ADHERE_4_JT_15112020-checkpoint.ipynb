# %% [markdown]
# # Imports

# %%
import pandas as pd
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline  
import statsmodels as st
import statsmodels.api as sm
from scipy import stats
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error, r2_score
from dateutil.parser import parse
import scipy.stats as scs
from pylab import rcParams
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams

#Stop warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read Data

# %%
def read_CLEAN_data(filename):
    #Read in CSV file
    dat = pd.read_csv(filename)
    #Convert datetimes
    dat["Date"] = pd.to_datetime(dat["Date"], format = '%Y-%m-%d').dt.date
    
    return dat
# 10 hours of non zeroes 
def ten_hours_non_zeros(df,hours):
    df1 = df.copy()
    df1['Not Zero'] = df1['Steps'] > 0
    df1 = df1.groupby('Date').sum()
    df1 = df1['Not Zero'] > hours 
    return df1
#Greater than 500 steps
def greater_than_certain_steps(df,min_steps):
    df1 = df.copy()
    df1 = df1.groupby('Date').sum()
    df1 = df1['Steps']> min_steps
    return df1


#Active in 3 time blocks 
def three_time_blocks(df):
    df1 = df.copy()
    bins = [-1,2,10,14,25,np.inf]
    names = ['3','1','2', '4', '5']
    df1['3timeblock'] = pd.cut(df1['Hour'],bins, labels = names)
    df1 = df1.replace({'3timeblock':r'4'},{'3timeblock':'3'},regex = True)
    df1 = df1.replace({'3timeblock':r'5'},{'3timeblock':'3'},regex = True)
    df1 = df1.groupby(['Date','3timeblock'], as_index=False)['Steps'].sum()
    df1['Steps within timeblock'] = df1['Steps']> 0 
    df1 = df1.groupby('Date').sum()
    df1 = df1['Steps within timeblock'] ==3 
    return df1

#Combining it all into 1 dataframe
def three_method_table(x):
    valid_1= ten_hours_non_zeros(x,10)
    valid_2= greater_than_certain_steps(x,500)
    valid_3= three_time_blocks(x)
    result = pd.concat([valid_1,valid_2,valid_3], axis=1, join='inner')
    result.reset_index(level=0, inplace=True)
    result.columns = ["Date", "Ten Hours Non Zero","Steps > Five Hundred","Three Timeblock"]
    result['All Three True'] = result["Three Timeblock"]*result["Ten Hours Non Zero"]*result["Steps > Five Hundred"]
    result_sum = result.sum()
    return result , result_sum

def filter_by_adherence(df, measure):
    df2 = three_method_table(df)[0]
    df3 = df.merge(df2,on ='Date')
    if(measure == 1):
        mask = (df3['Ten Hours Non Zero'] == True)
    elif(measure == 2):
        mask = (df3['Steps > Five Hundred'] == True)
    elif(measure == 3):
        mask = (df3['Three Timeblock'] == True)    
    elif(measure == 4):
        mask = (df3['All Three True'] == True)
    filtered_df = df3.loc[mask].drop(['Ten Hours Non Zero', 'Steps > Five Hundred', 'Three Timeblock', 'All Three True'], axis=1)

    return filtered_df

# Method 1 calculates daily steps based on all the step activity that is available during the day
def all_step_activity(df):
    
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 2 calculates daily steps based on the 10 most active hours of the day
def top_ten_most_active_hours(df):
    
    df = df.sort_values(by=["Date", "Steps"], ascending=False).groupby('Date').head(10)
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 3 calculates daily steps based on a 10 hour time block during the day
def ten_hour_time_block(df, start_hour, end_hour):
    
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    mask = (df['Hour'] >= start_hour) & (df['Hour'] <= end_hour)
    df = df.loc[mask]
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

def calculate_daily_steps(file_name, filter_measure, start_time, end_time):
    
    df = read_CLEAN_data(filename)
    filtered_df = filter_by_adherence(df, filter_measure)
    
    dailysteps_method2 = top_ten_most_active_hours(filtered_df)
    dailysteps_method1 = all_step_activity(filtered_df)
    dailysteps_method3 = ten_hour_time_block(filtered_df, start_time, end_time)
    
   
    return dailysteps_method1,dailysteps_method2,dailysteps_method3

# %%
filename = "../../../data/cleaned/User1.csv"

filter_measure = 3
start_time = 8
end_time = 18

ds_method1, ds_method2, ds_method3 = calculate_daily_steps(filename, filter_measure, start_time, end_time)

# %%
ds_method1.set_index('Date',inplace=True)
ds_method1.shape
# Out:
# (985, 1)

# %% [markdown]
# # Method 1

# %% [markdown]
# # Steps to take to implement (S)ARIMA

# %% [markdown]
# 1) Check for Seasonality <br />
# 2) Check for Stationarity <br />
# 3) If not Stationary perform Rolling/ Smoothing/ Shifting/ Differentiation <br />
# 4) Obtain SARIMA Parameters <br />
# 5) Data Splitting and Model evaluation by plots <br />
# 6) Data Forecasting

# %% [markdown]
# ### 1) Check For Seasonality

# %% [markdown]
# ##### Simple Plot

# %%
ds_method1.shape
# Out:
# (985, 1)

# %%
ds_method1.plot(figsize=(19, 4))
plt.ylabel("Nubmer of Steps")
plt.show()

# %% [markdown]
# #### Seasonal Decompose Plot

# %% [markdown]
# Using the command, we can decompose the time series into three distinct components: Trend, Seasonality and noise

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method1, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# After adherence, it appears that the data does not have much seasonality anymore. We can observe however, that there is a slight trend every 3 years that the user walks more during that year

# %% [markdown]
# # Check for data Stationarity

# %% [markdown]
# Will use this function to test for stationarity by using the **Augmented Dickey-Fuller test**

# %% [markdown]
# where <br />
# $H_0$: If failed to be rejected, time series data is not stationary <br />
# $H_1$: If $H_0$ is rejected, it means the time series data is stationary

# %%
def test_stationarity(timeseries):
    
    #Determine rolling statistics
    movingAverage = timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()
    
    #Plot rolling statistics
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.xlabel("Date")
    plt.ylabel("Number of Steps")
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    
    #Perform Dickey–Fuller test:
    print('Results of Dickey Fuller Test:')
    dftest = adfuller(timeseries['Steps'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(ds_method1)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic              -4.665864
# p-value                          0.000097
# #Lags Used                      11.000000
# Number of Observations Used    973.000000
# Critical Value (1%)             -3.437089
# Critical Value (5%)             -2.864515
# Critical Value (10%)            -2.568354
# dtype: float64

# %% [markdown]
# For this, we will use the $\alpha$ value of 0.05 to check against the p-value of 0.000097 to decide if we will accept or reject the $H_0$. As $\alpha$ > p-value, we can conclude that the data is stationary.

# %% [markdown]
# ## Making Data Stationary

# %% [markdown]
# As the data is stationary, we do not need to perform any transformation of the data to achieve stationarity.

# %% [markdown]
# ### Data Transformation to acheive Normality

# %% [markdown]
# #### Log Transformation

# %%
#Estimating trend
#ds_method1 = np.log(ds_method1)
#plt.plot(ds_method1)

# %% [markdown]
# # (S)ARIMA Parameters

# %% [markdown]
# #### ACF and PACF plots

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method1, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method1, ax=ax[1])
plt.show()

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(ds_method1, start_p=0, start_q=0,
                           max_p=10, max_q=10, m=12,
                           start_P=0,start_Q=0, seasonal=True,
                           d=0, D=0, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=18966.735, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=18837.481, Time=0.25 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=18867.322, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=20315.323, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=18849.667, Time=0.03 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=18836.405, Time=0.80 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=18831.235, Time=1.35 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=18838.006, Time=0.59 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=2.78 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=18832.417, Time=1.26 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=18919.564, Time=1.06 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=18813.369, Time=1.90 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=18816.597, Time=0.69 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=18813.082, Time=1.50 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=18814.674, Time=0.48 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=18805.624, Time=1.67 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=18808.027, Time=0.52 sec
#  ARIMA(3,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=2.22 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=18810.011, Time=0.93 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : AIC=18795.485, Time=2.16 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=18796.620, Time=0.68 sec
#  ARIMA(4,0,0)(2,0,1)[12] intercept   : AIC=18797.189, Time=2.46 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=18798.567, Time=1.10 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : AIC=18793.972, Time=2.74 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=18794.866, Time=1.02 sec
#  ARIMA(5,0,0)(2,0,1)[12] intercept   : AIC=18795.841, Time=3.33 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=18796.764, Time=1.38 sec
#  ARIMA(6,0,0)(2,0,0)[12] intercept   : AIC=18787.616, Time=3.49 sec
#  ARIMA(6,0,0)(1,0,0)[12] intercept   : AIC=18788.869, Time=1.35 sec
#  ARIMA(6,0,0)(2,0,1)[12] intercept   : AIC=18789.552, Time=3.93 sec
#  ARIMA(6,0,0)(1,0,1)[12] intercept   : AIC=18790.674, Time=1.43 sec
#  ARIMA(7,0,0)(2,0,0)[12] intercept   : AIC=18776.613, Time=3.67 sec
#  ARIMA(7,0,0)(1,0,0)[12] intercept   : AIC=18777.948, Time=1.36 sec
#  ARIMA(7,0,0)(2,0,1)[12] intercept   : AIC=18778.563, Time=3.60 sec
#  ARIMA(7,0,0)(1,0,1)[12] intercept   : AIC=18779.693, Time=2.17 sec
#  ARIMA(8,0,0)(2,0,0)[12] intercept   : AIC=18776.720, Time=5.85 sec
#  ARIMA(7,0,1)(2,0,0)[12] intercept   : AIC=18778.493, Time=3.54 sec
#  ARIMA(6,0,1)(2,0,0)[12] intercept   : AIC=18789.062, Time=3.52 sec
#  ARIMA(8,0,1)(2,0,0)[12] intercept   : AIC=18778.635, Time=4.68 sec
#  ARIMA(7,0,0)(2,0,0)[12]             : AIC=18820.118, Time=1.05 sec
#
# Best model:  ARIMA(7,0,0)(2,0,0)[12] intercept
# Total fit time: 72.731 seconds
# 18776.61316975535

# %% [markdown]
# So, the best set of paramters to select is  **ARIMA(3,0,1)(0,0,0)[0]** I selected m = 12 to represent the yearly number of months each 'season' runs for

# %%
model = sm.tsa.statespace.SARIMAX(ds_method1, order=(7,0,0), seasonal_order = (2,0,0,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.543464
#          Iterations: 2
#          Function evaluations: 231

# %%
train = ds_method1.loc['2014-12-08':'2019-02-18']
test = ds_method1.loc['2019-02-19':]
stepwise_model.fit(train)
# Out:
# ARIMA(order=(7, 0, 0), scoring_args={}, seasonal_order=(2, 0, 0, 12),
#       suppress_warnings=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method1,
                                order=(7,0,0),
                                seasonal_order=(2, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Steps   No. Observations:                  985
# Model:             SARIMAX(7, 0, 0)x(2, 0, 0, 12)   Log Likelihood               -9109.326
# Date:                            Tue, 17 Nov 2020   AIC                          18238.651
# Time:                                    17:19:16   BIC                          18287.258
# Sample:                                         0   HQIC                         18257.168
#                                             - 985
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2671      0.030      9.049      0.000       0.209       0.325
# ar.L2          0.1367      0.030      4.565      0.000       0.078       0.195
# ar.L3          0.0892      0.028      3.231      0.001       0.035       0.143
# ar.L4          0.1208      0.032      3.752      0.000       0.058       0.184
# ar.L5          0.0699      0.035      2.014      0.044       0.002       0.138
# ar.L6          0.1076      0.032      3.343      0.001       0.045       0.171
# ar.L7          0.1661      0.029      5.675      0.000       0.109       0.223
# ar.S.L12       0.0499      0.033      1.490      0.136      -0.016       0.116
# ar.S.L24       0.0537      0.031      1.713      0.087      -0.008       0.115
# sigma2      1.147e+07   6.48e-10   1.77e+16      0.000    1.15e+07    1.15e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.39   Jarque-Bera (JB):               386.95
# Prob(Q):                              0.53   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                             0.98
# Prob(H) (two-sided):                  0.18   Kurtosis:                         5.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.12e+30. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %% [markdown]
# ### (S)ARIMA Model Validation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# Train Set 80%, Validation 20%

# %%
# the 20% point test data is on the specified date below
split_date = '2019-02-18'
data = ds_method1['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(7, 0, 0),
                                seasonal_order=(2, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae1 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse1 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse1 = math.sqrt(mse1)
print(f'Mean Squared Error: {mse1.round(4)}')
print(f'Root Mean Squared Error: {round(rmse1,4)}')
print(f'Mean Absolute Error: {mae1.round(4)}')
# Out:
# Mean Squared Error: 32718501.5222
# Root Mean Squared Error: 5720.0089
# Mean Absolute Error: 4494.9877

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-02-18'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method1['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %% [markdown]
# # Method 2

# %%
#method_1.set_index('Date',inplace=True)
ds_method2.set_index('Date',inplace=True)
ds_method2.head()
# Out:
#                   Steps
# Date
# 2014-12-07  2693.000000
# 2014-12-08  6550.000000
# 2014-12-09  6879.000000
# 2014-12-10  7845.000000
# 2014-12-12  5886.460839

# %%
ds_method2.plot(figsize=(19, 4))
plt.ylabel("Nubmer of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method2, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
test_stationarity(ds_method2)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic            -5.808648e+00
# p-value                        4.454731e-07
# #Lags Used                     8.000000e+00
# Number of Observations Used    9.760000e+02
# Critical Value (1%)           -3.437068e+00
# Critical Value (5%)           -2.864506e+00
# Critical Value (10%)          -2.568349e+00
# dtype: float64

# %% [markdown]
# Again, data appears to be stationary so no transformation of the data was required. However, the data was not normal based on William's Observation. To normalise it, we logged the values

# %%
#Estimating trend
#ds_method2 = np.log(ds_method2)
#plt.plot(ds_method2)

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method2, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method2,ax=ax[1])
plt.show()

# %%
stepwise_model = auto_arima(ds_method2, start_p=0, start_q=0,
                           max_p=10, max_q=10, m=12,
                           start_P=0,start_Q=0, seasonal=True,
                           d=0, D=0, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=18895.916, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=18782.440, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=18808.140, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=20215.813, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=18792.034, Time=0.03 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=18781.803, Time=0.75 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=18776.909, Time=1.34 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=18783.038, Time=0.77 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=2.64 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=18777.557, Time=1.41 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=18858.169, Time=2.06 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=18759.974, Time=1.70 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=18762.884, Time=0.73 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=18759.810, Time=1.87 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=18760.982, Time=0.48 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=18753.576, Time=1.56 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=18755.586, Time=0.54 sec
#  ARIMA(3,0,0)(2,0,1)[12] intercept   : AIC=18754.580, Time=2.10 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=18757.583, Time=1.06 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : AIC=18743.712, Time=2.32 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=18744.687, Time=0.62 sec
#  ARIMA(4,0,0)(2,0,1)[12] intercept   : AIC=18745.287, Time=2.30 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=18746.659, Time=0.88 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : AIC=18742.442, Time=2.93 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=18743.234, Time=0.95 sec
#  ARIMA(5,0,0)(2,0,1)[12] intercept   : AIC=18744.218, Time=3.74 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=18745.170, Time=1.20 sec
#  ARIMA(6,0,0)(2,0,0)[12] intercept   : AIC=18736.058, Time=3.44 sec
#  ARIMA(6,0,0)(1,0,0)[12] intercept   : AIC=18737.251, Time=1.23 sec
#  ARIMA(6,0,0)(2,0,1)[12] intercept   : AIC=18737.926, Time=3.02 sec
#  ARIMA(6,0,0)(1,0,1)[12] intercept   : AIC=18739.113, Time=1.37 sec
#  ARIMA(7,0,0)(2,0,0)[12] intercept   : AIC=18726.278, Time=3.50 sec
#  ARIMA(7,0,0)(1,0,0)[12] intercept   : AIC=18727.668, Time=2.26 sec
#  ARIMA(7,0,0)(2,0,1)[12] intercept   : AIC=18728.165, Time=4.14 sec
#  ARIMA(7,0,0)(1,0,1)[12] intercept   : AIC=18729.473, Time=2.09 sec
#  ARIMA(8,0,0)(2,0,0)[12] intercept   : AIC=18726.182, Time=4.79 sec
#  ARIMA(8,0,0)(1,0,0)[12] intercept   : AIC=18727.100, Time=1.93 sec
#  ARIMA(8,0,0)(2,0,1)[12] intercept   : AIC=18728.140, Time=4.59 sec
#  ARIMA(8,0,0)(1,0,1)[12] intercept   : AIC=18728.898, Time=1.93 sec
#  ARIMA(9,0,0)(2,0,0)[12] intercept   : AIC=18723.208, Time=6.01 sec
#  ARIMA(9,0,0)(1,0,0)[12] intercept   : AIC=18723.650, Time=2.20 sec
#  ARIMA(9,0,0)(2,0,1)[12] intercept   : AIC=18725.189, Time=4.93 sec
#  ARIMA(9,0,0)(1,0,1)[12] intercept   : AIC=18725.435, Time=2.41 sec
#  ARIMA(10,0,0)(2,0,0)[12] intercept   : AIC=18724.036, Time=7.34 sec
#  ARIMA(9,0,1)(2,0,0)[12] intercept   : AIC=18725.154, Time=5.36 sec
#  ARIMA(8,0,1)(2,0,0)[12] intercept   : AIC=18728.107, Time=3.84 sec
#  ARIMA(10,0,1)(2,0,0)[12] intercept   : AIC=18725.986, Time=5.85 sec
#  ARIMA(9,0,0)(2,0,0)[12]             : AIC=inf, Time=1.52 sec
#
# Best model:  ARIMA(9,0,0)(2,0,0)[12] intercept
# Total fit time: 108.155 seconds
# 18723.20776444314

# %%
model = sm.tsa.statespace.SARIMAX(ds_method2, order=(9,0,0), seasonal_order = (2,0,0,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res,  ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res,  ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.508905
#          Iterations: 3
#          Function evaluations: 414

# %%
train = ds_method2.loc['2014-12-08':'2019-02-18']
test = ds_method2.loc['2019-02-19':]
stepwise_model.fit(train)
# Out:
# ARIMA(order=(9, 0, 0), scoring_args={}, seasonal_order=(2, 0, 0, 12),
#       suppress_warnings=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method2,
                                order=(9, 0, 0),
                                seasonal_order=(2, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Steps   No. Observations:                  985
# Model:             SARIMAX(9, 0, 0)x(2, 0, 0, 12)   Log Likelihood               -9057.809
# Date:                            Tue, 17 Nov 2020   AIC                          18139.618
# Time:                                    17:27:12   BIC                          18197.921
# Sample:                                         0   HQIC                         18161.830
#                                             - 985
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2373      0.030      7.861      0.000       0.178       0.296
# ar.L2          0.1158      0.030      3.902      0.000       0.058       0.174
# ar.L3          0.0688      0.028      2.427      0.015       0.013       0.124
# ar.L4          0.1063      0.033      3.217      0.001       0.042       0.171
# ar.L5          0.0509      0.035      1.450      0.147      -0.018       0.120
# ar.L6          0.0911      0.033      2.800      0.005       0.027       0.155
# ar.L7          0.1248      0.031      4.056      0.000       0.064       0.185
# ar.L8          0.0647      0.032      2.038      0.042       0.002       0.127
# ar.L9          0.1048      0.033      3.203      0.001       0.041       0.169
# ar.S.L12       0.0433      0.034      1.288      0.198      -0.023       0.109
# ar.S.L24       0.0426      0.031      1.372      0.170      -0.018       0.104
# sigma2      1.071e+07   7.54e-10   1.42e+16      0.000    1.07e+07    1.07e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):               416.84
# Prob(Q):                              0.69   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                             1.04
# Prob(H) (two-sided):                  0.04   Kurtosis:                         5.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.06e+30. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# the 20% point test data is on the specified date below
split_date = '2019-02-18'
data = ds_method2['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(9,0, 0),
                                seasonal_order=(2, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae2 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse2 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse2 = math.sqrt(mse2)
print(f'Mean Squared Error: {mse2.round(4)}')
print(f'Root Mean Squared Error: {round(rmse2,4)}')
print(f'Mean Absolute Error: {mae2.round(4)}')
# Out:
# Mean Squared Error: 24125017.1245
# Root Mean Squared Error: 4911.7224
# Mean Absolute Error: 3780.1287

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-02-18'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method2['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %% [markdown]
# # Method 3

# %%
#method_1.set_index('Date',inplace=True)
ds_method3.set_index('Date',inplace=True)

# %%
ds_method3.plot(figsize=(19, 4))
plt.ylabel("Nubmer of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method3, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
test_stationarity(ds_method3)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic              -5.062233
# p-value                          0.000017
# #Lags Used                      10.000000
# Number of Observations Used    974.000000
# Critical Value (1%)             -3.437082
# Critical Value (5%)             -2.864512
# Critical Value (10%)            -2.568352
# dtype: float64

# %%
#Estimating trend
#ds_method3 = np.log(ds_method3)
#plt.plot(ds_method3)

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method3, lags=30, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method3, lags=30, ax=ax[1])
plt.show()

# %%
stepwise_model = auto_arima(ds_method3, start_p=0, start_q=0,
                           max_p=7 , max_q=7, m=12,
                           start_P=0,start_Q=0, seasonal=True,
                           d=0, D=0, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=18685.124, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=18568.736, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=18597.044, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=19955.932, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=18573.687, Time=0.03 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=18569.813, Time=0.90 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=18569.908, Time=0.72 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=18568.520, Time=0.14 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=18568.234, Time=0.38 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=18569.483, Time=1.29 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=18653.076, Time=0.27 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=18544.874, Time=0.44 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=18543.212, Time=0.16 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=18544.225, Time=0.06 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=18544.920, Time=0.60 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=18542.989, Time=0.35 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=18544.643, Time=1.99 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=18546.414, Time=1.41 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=18530.321, Time=0.43 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=18530.007, Time=0.07 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=18530.517, Time=0.21 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=18532.321, Time=0.84 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=18522.179, Time=0.09 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=18522.521, Time=0.76 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=18522.663, Time=0.30 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=18524.521, Time=1.09 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=18519.336, Time=0.12 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=18520.288, Time=1.01 sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : AIC=18520.384, Time=0.33 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=18522.287, Time=1.41 sec
#  ARIMA(6,0,0)(0,0,0)[12] intercept   : AIC=18514.129, Time=0.14 sec
#  ARIMA(6,0,0)(1,0,0)[12] intercept   : AIC=18515.372, Time=1.18 sec
#  ARIMA(6,0,0)(0,0,1)[12] intercept   : AIC=18515.441, Time=0.35 sec
#  ARIMA(6,0,0)(1,0,1)[12] intercept   : AIC=18517.368, Time=1.86 sec
#  ARIMA(7,0,0)(0,0,0)[12] intercept   : AIC=18498.444, Time=0.22 sec
#  ARIMA(7,0,0)(1,0,0)[12] intercept   : AIC=18500.028, Time=1.46 sec
#  ARIMA(7,0,0)(0,0,1)[12] intercept   : AIC=18500.069, Time=0.37 sec
#  ARIMA(7,0,0)(1,0,1)[12] intercept   : AIC=18502.020, Time=1.63 sec
#  ARIMA(7,0,1)(0,0,0)[12] intercept   : AIC=18500.223, Time=0.36 sec
#  ARIMA(6,0,1)(0,0,0)[12] intercept   : AIC=18514.605, Time=0.27 sec
#  ARIMA(7,0,0)(0,0,0)[12]             : AIC=18538.062, Time=0.08 sec
#
# Best model:  ARIMA(7,0,0)(0,0,0)[12] intercept
# Total fit time: 23.696 seconds
# 18498.444262853453

# %%
model = sm.tsa.statespace.SARIMAX(ds_method3, order=(7,0,0), seasonal_order = (0,0,0,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, lags=30, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=30, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.402060
#          Iterations: 1
#          Function evaluations: 96

# %%
train = ds_method3.loc['2014-12-08':'2019-02-18']
test = ds_method3.loc['2019-02-19':]
stepwise_model.fit(train)
# Out:
# ARIMA(order=(7, 0, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method3,
                                order=(7,0,0),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                  985
# Model:               SARIMAX(7, 0, 0)   Log Likelihood               -9195.298
# Date:                Tue, 17 Nov 2020   AIC                          18406.596
# Time:                        17:28:12   BIC                          18445.680
# Sample:                             0   HQIC                         18421.467
#                                 - 985
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2578      0.031      8.385      0.000       0.198       0.318
# ar.L2          0.1456      0.030      4.880      0.000       0.087       0.204
# ar.L3          0.1140      0.029      3.988      0.000       0.058       0.170
# ar.L4          0.0969      0.030      3.193      0.001       0.037       0.156
# ar.L5          0.0728      0.033      2.224      0.026       0.009       0.137
# ar.L6          0.0942      0.033      2.875      0.004       0.030       0.158
# ar.L7          0.1796      0.030      5.926      0.000       0.120       0.239
# sigma2      8.593e+06   5.13e-10   1.68e+16      0.000    8.59e+06    8.59e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.24   Jarque-Bera (JB):               318.22
# Prob(Q):                              0.62   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                             0.93
# Prob(H) (two-sided):                  0.89   Kurtosis:                         5.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.08e+31. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# the 20% point test data is on the specified date below
split_date = '2019-02-18'
data = ds_method3['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(7,0,0),
                                seasonal_order=(0,0,0,12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae3 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse3 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse3 = math.sqrt(mse3)
print(f'Mean Squared Error: {mse3.round(4)}')
print(f'Root Mean Squared Error: {round(rmse3,4)}')
print(f'Mean Absolute Error: {mae3.round(4)}')
# Out:
# Mean Squared Error: 22689093.0432
# Root Mean Squared Error: 4763.3069
# Mean Absolute Error: 3684.1702

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-02-18'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method3['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Visitors')
plt.legend()
plt.show()

# %%
models = pd.DataFrame({
    'Method': ['Method 1', 'Method 2', 'Method 3'],
    'MSE': [round(mse1, 4), round(mse2, 4), round(mse3,4)],
    'RMSE': [round(rmse1,4 ), round(rmse2, 4), round(rmse3,4)],
    'MAE': [round(mae1, 4), round(mae2, 4), round(mae3,4)]})
models
# Out:
#      Method           MSE       RMSE        MAE
# 0  Method 1  3.271850e+07  5720.0089  4494.9877
# 1  Method 2  2.412502e+07  4911.7224  3780.1287
# 2  Method 3  2.268909e+07  4763.3069  3684.1702

# %% [markdown]
# Using this Adherence, all three(3) Methods of Step count are able to closely predict the step counts of the User_1. As such, to Determine the best method, we look at the RMSE which Method 3 has the lowest. Therefore,Method 3 performs the best here
