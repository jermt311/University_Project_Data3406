# %%
import xmltodict
import pandas as pd
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline  
import statsmodels as st
import statsmodels.api as sm
from scipy import stats
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error, r2_score
from dateutil.parser import parse
import scipy.stats as scs
from pylab import rcParams
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams

#Stop warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Read Data

# %%
def read_QS_data(filename):
    #Read in CSV file
    dat = pd.read_csv(filename)
    #Extract datetime information
    dat["Datetime"] = pd.to_datetime(dat["Start"], format = '%d-%b-%Y %H:%M')
    dat["Date"] = dat["Datetime"].dt.date
    dat["Hour"] = dat["Datetime"].dt.hour
    #Format columns
    dat = dat[["Date", "Hour", "Steps (count)"]]
    dat.columns = ["Date", "Hour", "Steps"]
    
    return dat

def read_Pacer_data(filename):
    #Read in the data
    dat = pd.read_csv(filename)
    #Select necessary columns
    dat = dat[["date","steps"]]
    #Extract datetime data
    dat["datetime"] = pd.to_datetime(dat["date"], format = '%m/%d/%Y, %H:%M:%S %z')
    dat["Date"] = dat["datetime"].dt.date
    dat["Hour"] = dat["datetime"].dt.hour
    dat["Min"] = dat["datetime"].dt.minute
    #Aggregate over the hours
    dat = dat.groupby(["Date","Hour"])["steps"].agg("sum").reset_index()
    #Relabel columns
    dat.columns = [["Date", "Hour", "Steps"]]
    
    return dat

def read_XML_data(filename):
    #Read in XML file
    with open(filename, 'r') as xml_file:
        input_data = xmltodict.parse(xml_file.read())
    #Extract record data from XML
    record_list = input_data['HealthData']['Record']
    df = pd.DataFrame(record_list)
    #Convert dates to datetime objects and steps to numeric
    date_format = '%Y-%m-%d %H:%M:%S %z'
    df['@startDate'] = pd.to_datetime(df['@startDate'], format = date_format)
    df['@endDate'] = pd.to_datetime(df['@endDate'], format = date_format)
    df['@value'] = pd.to_numeric(df['@value'])
    #Sum up values for each hour
    dat = df.resample("H", on="@startDate").sum().reset_index()
    #Extract date and hour information, and relabel columns
    dat["Date"] = dat["@startDate"].dt.date
    dat["Hour"] = dat["@startDate"].dt.hour
    dat["Steps"] = dat["@value"]
    dat = dat[["Date","Hour","Steps"]]
    
    return dat

def read_CLEAN_data(filename):
    #Read in CSV file
    dat = pd.read_csv(filename)
    #Convert datetimes
    dat["Date"] = pd.to_datetime(dat["Date"], format = '%Y-%m-%d').dt.date
    
    return dat

# %% [markdown]
# #### Input Pipeline

# %%
def read_step_data(filename, read_type):
    read_type = read_type.lower()
    print("reading: " + filename)
    if read_type == "pacer":
        return read_Pacer_data(filename)
    elif read_type == "qsaccess" or read_type == "qs":
        return read_QS_data(filename)
    elif read_type == "xml":
        return read_XML_data(filename)
    elif read_type == "clean" or read_type == "cleaned":
        return read_CLEAN_data(filename)
    else:
        raise Exception("Not a valid file type to read! Use pacer, qs, xml or clean")

# %% [markdown]
# #### Adherence and Methods

# %%
# 10 hours of non zeroes 
def ten_hours_non_zeros(df,hours):
    df1 = df.copy()
    df1['Not Zero'] = df1['Steps'] > 0
    df1 = df1.groupby('Date').sum()
    df1 = df1['Not Zero'] > hours 
    return df1

#Greater than 500 steps
def greater_than_certain_steps(df,min_steps):
    df1 = df.copy()
    df1 = df1.groupby('Date').sum()
    df1 = df1['Steps']> min_steps
    return df1


#Active in 3 time blocks 
def three_time_blocks(df):
    df1 = df.copy()
    bins = [-1,2,10,14,25,np.inf]
    names = ['3','1','2', '4', '5']
    df1['3timeblock'] = pd.cut(df1['Hour'],bins, labels = names)
    df1 = df1.replace({'3timeblock':r'4'},{'3timeblock':'3'},regex = True)
    df1 = df1.replace({'3timeblock':r'5'},{'3timeblock':'3'},regex = True)
    df1 = df1.groupby(['Date','3timeblock'], as_index=False)['Steps'].sum()
    df1['Steps within timeblock'] = df1['Steps']> 0 
    df1 = df1.groupby('Date').sum()
    df1 = df1['Steps within timeblock'] ==3 
    return df1

#Combining it all into 1 dataframe
def three_method_table(x):
    valid_1= ten_hours_non_zeros(x,10)
    valid_2= greater_than_certain_steps(x,500)
    valid_3= three_time_blocks(x)
    result = pd.concat([valid_1,valid_2,valid_3], axis=1, join='inner')
    result.reset_index(level=0, inplace=True)
    result.columns = ["Date", "Ten Hours Non Zero","Steps > Five Hundred","Three Timeblock"]
    result['All Three True'] = result["Three Timeblock"]*result["Ten Hours Non Zero"]*result["Steps > Five Hundred"]
    result_sum = result.sum()
    return result , result_sum

def filter_by_adherence(df, measure):
    df2 = three_method_table(df)[0]
    df3 = df.merge(df2,on ='Date')
    if(measure == 1):
        mask = (df3['Ten Hours Non Zero'] == True)
    elif(measure == 2):
        mask = (df3['Steps > Five Hundred'] == True)
    elif(measure == 3):
        mask = (df3['Three Timeblock'] == True)    
    elif(measure == 4):
        mask = (df3['All Three True'] == True)
    filtered_df = df3.loc[mask].drop(['Ten Hours Non Zero', 'Steps > Five Hundred', 'Three Timeblock', 'All Three True'], axis=1)

    return filtered_df

# Method 1 calculates daily steps based on all the step activity that is available during the day
def all_step_activity(df):
    df = df.copy()
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 2 calculates daily steps based on the 10 most active hours of the day
def top_ten_most_active_hours(df):
    df = df.copy()
    df = df.sort_values(by=["Date", "Steps"], ascending=False).groupby('Date').head(10)
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 3 calculates daily steps based on a 10 hour time block during the day
def ten_hour_time_block(df, start_hour, end_hour):
    df = df.copy()
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    mask = (df['Hour'] >= start_hour) & (df['Hour'] <= end_hour)
    df = df.loc[mask]
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

def calculate_daily_steps(file_name, read_type, filter_measure, start_time, end_time):
    df = read_step_data(filename, read_type)
    filtered_df = filter_by_adherence(df, filter_measure)
    dailysteps_method2 = top_ten_most_active_hours(filtered_df)
    dailysteps_method1 = all_step_activity(filtered_df)
    dailysteps_method3 = ten_hour_time_block(filtered_df, start_time, end_time)
    
   
    return dailysteps_method1,dailysteps_method2,dailysteps_method3

# %%
filename = "serena.csv"

filter_measure = 2
read_type = "clean"
start_time = 8
end_time = 18

ds_method1, ds_method2, ds_method3 = calculate_daily_steps(filename, read_type, filter_measure, start_time, end_time)
# Out:
# reading: serena.csv

# %% [markdown]
# #### Method 1

# %%
ds_method1.set_index('Date',inplace=True)
ds_method1.shape
# Out:
# (1623, 1)

# %%
ds_method1.plot(figsize=(19, 4))
plt.ylabel("Number of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method1, model='additive', freq = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# The data still has some missing seasonality, but we'll still use SARIMA.

# %% [markdown]
# #### Check for data stationary

# %%
def test_stationarity(timeseries):
    
    #Determine rolling statistics
    movingAverage = timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()
    
    #Plot rolling statistics
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.xlabel("Date")
    plt.ylabel("Number of Steps")
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    
    #Perform Dickey–Fuller test:
    print('Results of Dickey Fuller Test:')
    dftest = adfuller(timeseries['Steps'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(ds_method1)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic               -4.631438
# p-value                           0.000113
# #Lags Used                       17.000000
# Number of Observations Used    1605.000000
# Critical Value (1%)              -3.434431
# Critical Value (5%)              -2.863342
# Critical Value (10%)             -2.567730
# dtype: float64

# %% [markdown]
# For this, we will use the $\alpha$ value of 0.05 to check against the p-value of 0.000113 to decide if we will accept or reject the $H_0$. As $\alpha$ > p-value, we can conclude that the data is stationary.

# %% [markdown]
# #### (S)ARIMA Parameters

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method1, ax=ax[0], lags = 40)
fig = sm.graphics.tsa.plot_pacf(ds_method1, ax=ax[1], lags = 40)
plt.show()

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(ds_method1, start_p=0, start_q=0,
                           max_p=5, max_q=7, m=12,
                            seasonal=True,
                           d=0 , trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=31496.952, BIC=31518.520, Fit time=3.649 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=30911.048, BIC=30921.832, Fit time=0.082 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=30773.842, BIC=30795.410, Fit time=0.913 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=30802.793, BIC=30824.361, Fit time=0.600 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=30777.634, BIC=30793.810, Fit time=0.154 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=30772.930, BIC=30799.890, Fit time=2.748 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=30771.727, BIC=30804.079, Fit time=7.945 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=30876.161, BIC=30903.122, Fit time=4.439 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=30750.395, BIC=30788.139, Fit time=6.402 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=30753.079, BIC=30796.215, Fit time=13.697 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=30748.837, BIC=30797.365, Fit time=11.102 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=30749.541, BIC=30792.677, Fit time=4.975 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=30750.776, BIC=30793.912, Fit time=5.346 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=30747.458, BIC=30801.379, Fit time=15.759 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=30763.510, BIC=30812.038, Fit time=11.101 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=30748.524, BIC=30807.836, Fit time=16.096 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=30750.058, BIC=30798.587, Fit time=10.582 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=30750.979, BIC=30810.291, Fit time=16.531 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=30749.362, BIC=30792.499, Fit time=10.057 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=30743.136, BIC=30807.841, Fit time=15.138 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=30734.185, BIC=30793.497, Fit time=15.170 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=30732.437, BIC=30786.357, Fit time=4.869 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=30718.482, BIC=30761.618, Fit time=1.974 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=30721.413, BIC=30759.157, Fit time=0.968 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=30697.477, BIC=30746.006, Fit time=3.745 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=30720.414, BIC=30763.550, Fit time=0.752 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=30676.369, BIC=30730.289, Fit time=3.682 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=30678.234, BIC=30737.547, Fit time=8.074 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=30677.555, BIC=30736.868, Fit time=6.084 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=30750.153, BIC=30814.858, Fit time=7.601 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=30709.158, BIC=30757.686, Fit time=3.636 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=30661.493, BIC=30720.805, Fit time=3.709 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=30662.355, BIC=30727.060, Fit time=8.614 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=30663.489, BIC=30728.193, Fit time=8.768 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=30670.142, BIC=30724.062, Fit time=2.393 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=30657.704, BIC=30722.409, Fit time=4.333 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=30663.798, BIC=30723.110, Fit time=4.186 seconds
# Total fit time: 245.922 seconds
# 30657.704338787575

# %% [markdown]
# So, the best set of paramters to select is ARIMA(5,0,5)(0,0,0,12). I selected m = 12 to represent the yearly number of months each 'season' runs for.

# %%
model = sm.tsa.statespace.SARIMAX(ds_method1, order=(5,0,5), seasonal_order = (0,0,0,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.440589
#          Iterations: 4
#          Function evaluations: 516

# %%
train = ds_method1.loc['2015-11-29':'2019-09-10']
test = ds_method1.loc['2020-10-14':]
stepwise_model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=None, method=None, order=(5, 0, 5),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 0, 0, 12), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend=None,
#    with_intercept=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method1,
                                order=(5, 0, 5),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                 1623
# Model:               SARIMAX(5, 0, 5)   Log Likelihood              -15255.821
# Date:                Wed, 18 Nov 2020   AIC                          30533.643
# Time:                        15:06:34   BIC                          30592.914
# Sample:                             0   HQIC                         30555.640
#                                - 1623
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2317      0.067      3.440      0.001       0.100       0.364
# ar.L2          1.3191      0.056     23.533      0.000       1.209       1.429
# ar.L3         -0.9294      0.117     -7.955      0.000      -1.158      -0.700
# ar.L4         -0.3655      0.055     -6.591      0.000      -0.474      -0.257
# ar.L5          0.7419      0.068     10.853      0.000       0.608       0.876
# ma.L1          0.0106      0.077      0.136      0.892      -0.141       0.162
# ma.L2         -1.3640      0.073    -18.774      0.000      -1.506      -1.222
# ma.L3          0.6780      0.142      4.758      0.000       0.399       0.957
# ma.L4          0.5163      0.066      7.843      0.000       0.387       0.645
# ma.L5         -0.6290      0.081     -7.805      0.000      -0.787      -0.471
# sigma2      9.109e+06   5.64e-09   1.61e+15      0.000    9.11e+06    9.11e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):               565.25
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.98   Skew:                             0.94
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.92e+31. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %% [markdown]
# #### (S)ARIMA Model Validation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# the 20% point test data is on the specified date below
split_date = '2019-09-10'
data = ds_method1['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(5, 0, 5),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae1 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse1 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse1 = math.sqrt(mse1)
print(f'Mean Squared Error: {mse1.round(4)}')
print(f'Root Mean Squared Error: {round(rmse1,4)}')
print(f'Mean Absolute Error: {mae1.round(4)}')
# Out:
# Mean Squared Error: 21099010.7677
# Root Mean Squared Error: 4593.366
# Mean Absolute Error: 3847.3442

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-09-10'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method1['2015':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %% [markdown]
# #### Method 2

# %%
ds_method2.set_index('Date',inplace=True)
ds_method2.head()
# Out:
#                    Steps
# Date
# 2015-11-29   4115.703713
# 2015-11-30   4013.000000
# 2015-12-01   3191.000000
# 2015-12-02   2724.000000
# 2015-12-03  12851.000000

# %%
ds_method2.plot(figsize=(19, 4))
plt.ylabel("Number of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method2, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# Again, data is missing some seasonal data

# %%
test_stationarity(ds_method2)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic               -4.565127
# p-value                           0.000150
# #Lags Used                       17.000000
# Number of Observations Used    1605.000000
# Critical Value (1%)              -3.434431
# Critical Value (5%)              -2.863342
# Critical Value (10%)             -2.567730
# dtype: float64

# %% [markdown]
# Data appears to be stationary

# %%
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method2, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method2,ax=ax[1])
plt.show()

# %%
stepwise_model = auto_arima(ds_method2, start_p=0, start_q=0,
                           max_p=5, max_q=6, m=12,
                            seasonal=True,
                           d=0,  trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=30810.214, BIC=30831.783, Fit time=1.597 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=30834.755, BIC=30845.539, Fit time=0.071 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=30696.834, BIC=30718.402, Fit time=0.683 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=30725.942, BIC=30747.511, Fit time=0.537 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=30700.323, BIC=30716.499, Fit time=0.147 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=30695.450, BIC=30722.410, Fit time=2.617 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=30694.228, BIC=30726.580, Fit time=8.362 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=30798.940, BIC=30825.900, Fit time=5.229 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=30673.419, BIC=30711.163, Fit time=6.895 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=30675.293, BIC=30718.430, Fit time=11.944 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=30671.250, BIC=30719.778, Fit time=11.466 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=30672.529, BIC=30715.665, Fit time=4.638 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=30673.690, BIC=30716.826, Fit time=5.757 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=30669.751, BIC=30723.672, Fit time=16.532 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=30685.011, BIC=30733.539, Fit time=8.212 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=30670.729, BIC=30730.041, Fit time=17.033 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=30673.020, BIC=30721.548, Fit time=14.404 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=30672.090, BIC=30731.402, Fit time=18.203 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=30672.431, BIC=30715.567, Fit time=12.434 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=30664.472, BIC=30729.176, Fit time=22.830 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=30663.018, BIC=30722.330, Fit time=13.494 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=30653.263, BIC=30707.183, Fit time=6.129 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=30641.020, BIC=30684.156, Fit time=1.828 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=30644.188, BIC=30681.932, Fit time=1.405 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=30620.337, BIC=30668.865, Fit time=3.228 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=30643.024, BIC=30686.160, Fit time=0.913 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=30601.541, BIC=30655.461, Fit time=3.562 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=30603.402, BIC=30662.714, Fit time=7.393 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=30602.901, BIC=30662.213, Fit time=7.279 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=30671.948, BIC=30736.652, Fit time=8.531 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=30602.306, BIC=30650.834, Fit time=3.255 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=30587.265, BIC=30646.578, Fit time=4.073 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=30588.104, BIC=30652.809, Fit time=8.346 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=30589.297, BIC=30654.001, Fit time=8.596 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=30595.255, BIC=30649.175, Fit time=2.351 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=30578.365, BIC=30643.070, Fit time=4.097 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=30582.237, BIC=30641.550, Fit time=4.200 seconds
# Total fit time: 258.327 seconds
# 30578.365446474698

# %% [markdown]
# Best SARIMA is  order=(5,0,5) seasonal_order=(0, 0, 0, 12)

# %%
model = sm.tsa.statespace.SARIMAX(ds_method2, order=(5,0,5), seasonal_order = (0,0,0,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res,  ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res,  ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.416418
#          Iterations: 4
#          Function evaluations: 518

# %%
train = ds_method2.loc['2015-11-29':'2019-09-10']
test = ds_method2.loc['2020-10-14':]
stepwise_model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=None, method=None, order=(5, 0, 5),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 0, 0, 12), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend=None,
#    with_intercept=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method2,
                                order=(4,0,5),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                 1623
# Model:               SARIMAX(4, 0, 5)   Log Likelihood              -15208.619
# Date:                Wed, 18 Nov 2020   AIC                          30437.238
# Time:                        15:11:52   BIC                          30491.121
# Sample:                             0   HQIC                         30457.236
#                                - 1623
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2246      0.141      8.674      0.000       0.948       1.501
# ar.L2         -0.2561      0.296     -0.866      0.386      -0.836       0.323
# ar.L3         -0.8237      0.294     -2.798      0.005      -1.401      -0.247
# ar.L4          0.8543      0.140      6.119      0.000       0.581       1.128
# ma.L1         -1.0938      0.142     -7.691      0.000      -1.373      -0.815
# ma.L2          0.2283      0.286      0.798      0.425      -0.333       0.789
# ma.L3          0.8085      0.289      2.802      0.005       0.243       1.374
# ma.L4         -0.7405      0.137     -5.390      0.000      -1.010      -0.471
# ma.L5         -0.0799      0.024     -3.289      0.001      -0.128      -0.032
# sigma2      8.794e+06   4.26e-09   2.06e+15      0.000    8.79e+06    8.79e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               619.82
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.10   Skew:                             0.97
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.2e+32. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# the 20% point test data is on the specified date below
split_date = '2019-09-10'
data = ds_method2['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(4,0,5),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae2 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse2 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse2 = math.sqrt(mse2)
print(f'Mean Squared Error: {mse2.round(4)}')
print(f'Root Mean Squared Error: {round(rmse2,4)}')
print(f'Mean Absolute Error: {mae2.round(4)}')
# Out:
# Mean Squared Error: 20618448.3266
# Root Mean Squared Error: 4540.7542
# Mean Absolute Error: 3842.0138

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-09-10'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method2['2015':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %% [markdown]
# #### Method 3

# %%
ds_method3.set_index('Date',inplace=True)
ds_method3.head()
# Out:
#                    Steps
# Date
# 2015-11-29   4080.573591
# 2015-11-30   3906.552367
# 2015-12-01   2979.000000
# 2015-12-02   2544.000000
# 2015-12-03  12674.000000

# %%
ds_method3.plot(figsize=(19, 4))
plt.ylabel("Number of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method3, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# Again, our data is missing some seasonal data

# %%
test_stationarity(ds_method3)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic               -4.832292
# p-value                           0.000047
# #Lags Used                       17.000000
# Number of Observations Used    1605.000000
# Critical Value (1%)              -3.434431
# Critical Value (5%)              -2.863342
# Critical Value (10%)             -2.567730
# dtype: float64

# %% [markdown]
# P-value is significant, our data is stationary

# %%
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method3, lags=30, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method3, lags=30, ax=ax[1])
plt.show()

# %%
stepwise_model = auto_arima(ds_method3, start_p=0, start_q=0,
                           max_p=4, max_q=6, m=12,
                            seasonal=True,
                           d=0,  trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=30744.885, BIC=30766.453, Fit time=5.458 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=30402.801, BIC=30413.585, Fit time=0.057 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=30329.898, BIC=30351.466, Fit time=0.840 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=30339.584, BIC=30361.152, Fit time=0.830 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=30334.487, BIC=30350.663, Fit time=0.187 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=30331.298, BIC=30358.258, Fit time=2.980 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=30330.307, BIC=30357.267, Fit time=3.712 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=30329.429, BIC=30361.782, Fit time=7.103 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=30385.023, BIC=30411.983, Fit time=6.208 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=30393.744, BIC=30431.488, Fit time=11.976 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=30317.295, BIC=30360.432, Fit time=19.360 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=30317.729, BIC=30355.473, Fit time=14.574 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=30321.285, BIC=30359.029, Fit time=6.239 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=30320.912, BIC=30369.441, Fit time=17.647 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=30321.373, BIC=30353.725, Fit time=3.378 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=30318.081, BIC=30366.609, Fit time=21.291 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=30343.213, BIC=30391.741, Fit time=21.011 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=30315.513, BIC=30369.433, Fit time=27.993 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=30313.572, BIC=30362.100, Fit time=11.810 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=30311.424, BIC=30354.561, Fit time=5.139 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=30312.930, BIC=30350.674, Fit time=3.412 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=30314.564, BIC=30363.092, Fit time=4.949 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=30323.371, BIC=30361.115, Fit time=2.906 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=30284.793, BIC=30333.322, Fit time=9.107 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=30272.178, BIC=30331.490, Fit time=11.143 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=30269.692, BIC=30323.613, Fit time=5.465 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=30271.050, BIC=30330.363, Fit time=12.247 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=30353.033, BIC=30417.737, Fit time=15.791 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=30308.859, BIC=30357.387, Fit time=7.454 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=30296.244, BIC=30344.772, Fit time=7.377 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=30261.548, BIC=30320.861, Fit time=5.903 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=30264.864, BIC=30329.568, Fit time=13.257 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=30262.555, BIC=30327.260, Fit time=15.052 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=30294.247, BIC=30348.167, Fit time=8.464 seconds
# Fit ARIMA: order=(4, 0, 6) seasonal_order=(0, 0, 0, 12); AIC=30252.626, BIC=30317.331, Fit time=7.272 seconds
# Fit ARIMA: order=(3, 0, 6) seasonal_order=(0, 0, 0, 12); AIC=30262.286, BIC=30321.598, Fit time=9.240 seconds
# Total fit time: 334.385 seconds
# 30252.626246683772

# %% [markdown]
# Best ARIMA order=(4, 0, 6) seasonal_order=(0, 0, 0, 12)

# %%
model = sm.tsa.statespace.SARIMAX(ds_method3, order=(4,0,6), seasonal_order = (0,0,0,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, lags=30, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=30, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.305099
#          Iterations: 2
#          Function evaluations: 269

# %%
train = ds_method3.loc['2015-11-29':'2019-09-10']
test = ds_method3.loc['2020-10-14':]
stepwise_model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=None, method=None, order=(4, 0, 6),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 0, 0, 12), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend=None,
#    with_intercept=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method3,
                                order=(4,0,6),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                 1623
# Model:               SARIMAX(4, 0, 6)   Log Likelihood              -15031.168
# Date:                Wed, 18 Nov 2020   AIC                          30084.335
# Time:                        15:19:38   BIC                          30143.600
# Sample:                             0   HQIC                         30106.331
#                                - 1623
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1263      0.122      9.230      0.000       0.887       1.365
# ar.L2          0.0076      0.189      0.040      0.968      -0.362       0.377
# ar.L3         -0.8156      0.160     -5.086      0.000      -1.130      -0.501
# ar.L4          0.6811      0.088      7.709      0.000       0.508       0.854
# ma.L1         -0.9980      0.124     -8.023      0.000      -1.242      -0.754
# ma.L2         -0.0966      0.180     -0.537      0.591      -0.449       0.256
# ma.L3          0.7159      0.150      4.771      0.000       0.422       1.010
# ma.L4         -0.5445      0.086     -6.308      0.000      -0.714      -0.375
# ma.L5         -0.0389      0.039     -0.993      0.321      -0.116       0.038
# ma.L6          0.0428      0.030      1.414      0.157      -0.017       0.102
# sigma2      7.169e+06   8.28e-08   8.66e+13      0.000    7.17e+06    7.17e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1040.20
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.83   Skew:                             1.16
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.39e+29. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# the 20% point test data is on the specified date below
split_date = '2019-09-10'
data = ds_method3['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(4,0,6),
                                seasonal_order=(0,0,0,12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae3 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse3 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse3 = math.sqrt(mse3)
print(f'Mean Squared Error: {mse3.round(4)}')
print(f'Root Mean Squared Error: {round(rmse3,4)}')
print(f'Mean Absolute Error: {mae3.round(4)}')
# Out:
# Mean Squared Error: 16798555.9113
# Root Mean Squared Error: 4098.6041
# Mean Absolute Error: 3509.0284

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-09-10'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method3['2015':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %%
models = pd.DataFrame({
    'Method': ['Method 1', 'Method 2', 'Method 3'],
    'MSE': [round(mse1, 4), round(mse2, 4), round(mse3,4)],
    'RMSE': [round(rmse1,4 ), round(rmse2, 4), round(rmse3,4)],
    'MAE': [round(mae1, 4), round(mae2, 4), round(mae3,4)]})
models
# Out:
#      Method           MSE       RMSE        MAE
# 0  Method 1  2.109901e+07  4593.3660  3847.3442
# 1  Method 2  2.061845e+07  4540.7542  3842.0138
# 2  Method 3  1.679856e+07  4098.6041  3509.0284

# %% [markdown]
# Based on the above predictions, we can observe that **Method 1** and **Method 2** have a very similar prediction with **Method 1** performing the worst. However, the **RMSE** value of **Model 3** is lower, therefore, we can conclude that the **Method 3** performs the best here.
