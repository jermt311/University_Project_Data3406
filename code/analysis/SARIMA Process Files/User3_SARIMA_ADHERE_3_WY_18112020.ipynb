# %%
import xmltodict
import pandas as pd
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline  
import statsmodels as st
import statsmodels.api as sm
from scipy import stats
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error, r2_score
from dateutil.parser import parse
import scipy.stats as scs
from pylab import rcParams
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams

#Stop warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Read Data

# %%
def read_QS_data(filename):
    #Read in CSV file
    dat = pd.read_csv(filename)
    #Extract datetime information
    dat["Datetime"] = pd.to_datetime(dat["Start"], format = '%d-%b-%Y %H:%M')
    dat["Date"] = dat["Datetime"].dt.date
    dat["Hour"] = dat["Datetime"].dt.hour
    #Format columns
    dat = dat[["Date", "Hour", "Steps (count)"]]
    dat.columns = ["Date", "Hour", "Steps"]
    
    return dat

def read_Pacer_data(filename):
    #Read in the data
    dat = pd.read_csv(filename)
    #Select necessary columns
    dat = dat[["date","steps"]]
    #Extract datetime data
    dat["datetime"] = pd.to_datetime(dat["date"], format = '%m/%d/%Y, %H:%M:%S %z')
    dat["Date"] = dat["datetime"].dt.date
    dat["Hour"] = dat["datetime"].dt.hour
    dat["Min"] = dat["datetime"].dt.minute
    #Aggregate over the hours
    dat = dat.groupby(["Date","Hour"])["steps"].agg("sum").reset_index()
    #Relabel columns
    dat.columns = [["Date", "Hour", "Steps"]]
    
    return dat

def read_XML_data(filename):
    #Read in XML file
    with open(filename, 'r') as xml_file:
        input_data = xmltodict.parse(xml_file.read())
    #Extract record data from XML
    record_list = input_data['HealthData']['Record']
    df = pd.DataFrame(record_list)
    #Convert dates to datetime objects and steps to numeric
    date_format = '%Y-%m-%d %H:%M:%S %z'
    df['@startDate'] = pd.to_datetime(df['@startDate'], format = date_format)
    df['@endDate'] = pd.to_datetime(df['@endDate'], format = date_format)
    df['@value'] = pd.to_numeric(df['@value'])
    #Sum up values for each hour
    dat = df.resample("H", on="@startDate").sum().reset_index()
    #Extract date and hour information, and relabel columns
    dat["Date"] = dat["@startDate"].dt.date
    dat["Hour"] = dat["@startDate"].dt.hour
    dat["Steps"] = dat["@value"]
    dat = dat[["Date","Hour","Steps"]]
    
    return dat

def read_CLEAN_data(filename):
    #Read in CSV file
    dat = pd.read_csv(filename)
    #Convert datetimes
    dat["Date"] = pd.to_datetime(dat["Date"], format = '%Y-%m-%d').dt.date
    
    return dat

# %% [markdown]
# #### Input Pipeline

# %%
def read_step_data(filename, read_type):
    read_type = read_type.lower()
    print("reading: " + filename)
    if read_type == "pacer":
        return read_Pacer_data(filename)
    elif read_type == "qsaccess" or read_type == "qs":
        return read_QS_data(filename)
    elif read_type == "xml":
        return read_XML_data(filename)
    elif read_type == "clean" or read_type == "cleaned":
        return read_CLEAN_data(filename)
    else:
        raise Exception("Not a valid file type to read! Use pacer, qs, xml or clean")

# %% [markdown]
# #### Adherence and Methods

# %%
# 10 hours of non zeroes 
def ten_hours_non_zeros(df,hours):
    df1 = df.copy()
    df1['Not Zero'] = df1['Steps'] > 0
    df1 = df1.groupby('Date').sum()
    df1 = df1['Not Zero'] > hours 
    return df1

#Greater than 500 steps
def greater_than_certain_steps(df,min_steps):
    df1 = df.copy()
    df1 = df1.groupby('Date').sum()
    df1 = df1['Steps']> min_steps
    return df1


#Active in 3 time blocks 
def three_time_blocks(df):
    df1 = df.copy()
    bins = [-1,2,10,14,25,np.inf]
    names = ['3','1','2', '4', '5']
    df1['3timeblock'] = pd.cut(df1['Hour'],bins, labels = names)
    df1 = df1.replace({'3timeblock':r'4'},{'3timeblock':'3'},regex = True)
    df1 = df1.replace({'3timeblock':r'5'},{'3timeblock':'3'},regex = True)
    df1 = df1.groupby(['Date','3timeblock'], as_index=False)['Steps'].sum()
    df1['Steps within timeblock'] = df1['Steps']> 0 
    df1 = df1.groupby('Date').sum()
    df1 = df1['Steps within timeblock'] ==3 
    return df1

#Combining it all into 1 dataframe
def three_method_table(x):
    valid_1= ten_hours_non_zeros(x,10)
    valid_2= greater_than_certain_steps(x,500)
    valid_3= three_time_blocks(x)
    result = pd.concat([valid_1,valid_2,valid_3], axis=1, join='inner')
    result.reset_index(level=0, inplace=True)
    result.columns = ["Date", "Ten Hours Non Zero","Steps > Five Hundred","Three Timeblock"]
    result['All Three True'] = result["Three Timeblock"]*result["Ten Hours Non Zero"]*result["Steps > Five Hundred"]
    result_sum = result.sum()
    return result , result_sum

def filter_by_adherence(df, measure):
    df2 = three_method_table(df)[0]
    df3 = df.merge(df2,on ='Date')
    if(measure == 1):
        mask = (df3['Ten Hours Non Zero'] == True)
    elif(measure == 2):
        mask = (df3['Steps > Five Hundred'] == True)
    elif(measure == 3):
        mask = (df3['Three Timeblock'] == True)    
    elif(measure == 4):
        mask = (df3['All Three True'] == True)
    filtered_df = df3.loc[mask].drop(['Ten Hours Non Zero', 'Steps > Five Hundred', 'Three Timeblock', 'All Three True'], axis=1)

    return filtered_df

# Method 1 calculates daily steps based on all the step activity that is available during the day
def all_step_activity(df):
    df = df.copy()
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 2 calculates daily steps based on the 10 most active hours of the day
def top_ten_most_active_hours(df):
    df = df.copy()
    df = df.sort_values(by=["Date", "Steps"], ascending=False).groupby('Date').head(10)
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

# Method 3 calculates daily steps based on a 10 hour time block during the day
def ten_hour_time_block(df, start_hour, end_hour):
    df = df.copy()
    df["Date"] = pd.to_datetime(df["Date"],format='%Y-%m-%d')
    mask = (df['Hour'] >= start_hour) & (df['Hour'] <= end_hour)
    df = df.loc[mask]
    df.index = df["Date"]
    daily_step_count = df.drop(['Hour'], axis=1).resample('D').sum(min_count=1).dropna().reset_index()
    
    return(daily_step_count)

def calculate_daily_steps(file_name, read_type, filter_measure, start_time, end_time):
    df = read_step_data(filename, read_type)
    filtered_df = filter_by_adherence(df, filter_measure)
    dailysteps_method2 = top_ten_most_active_hours(filtered_df)
    dailysteps_method1 = all_step_activity(filtered_df)
    dailysteps_method3 = ten_hour_time_block(filtered_df, start_time, end_time)
    
   
    return dailysteps_method1,dailysteps_method2,dailysteps_method3

# %%
filename = "serena.csv"

filter_measure = 4
read_type = "clean"
start_time = 8
end_time = 18

ds_method1, ds_method2, ds_method3 = calculate_daily_steps(filename, read_type, filter_measure, start_time, end_time)
# Out:
# reading: serena.csv

# %% [markdown]
# #### Method 1

# %%
ds_method1.set_index('Date',inplace=True)
ds_method1.shape
# Out:
# (1016, 1)

# %%
ds_method1.plot(figsize=(19, 4))
plt.ylabel("Number of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method1, model='additive', freq = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# The data still has some missing seasonality, but we'll still use SARIMA.

# %% [markdown]
# #### Check for data stationary

# %%
def test_stationarity(timeseries):
    
    #Determine rolling statistics
    movingAverage = timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()
    
    #Plot rolling statistics
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.xlabel("Date")
    plt.ylabel("Number of Steps")
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    
    #Perform Dickey–Fuller test:
    print('Results of Dickey Fuller Test:')
    dftest = adfuller(timeseries['Steps'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(ds_method1)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic              -3.182676
# p-value                          0.021010
# #Lags Used                      17.000000
# Number of Observations Used    998.000000
# Critical Value (1%)             -3.436919
# Critical Value (5%)             -2.864440
# Critical Value (10%)            -2.568314
# dtype: float64

# %% [markdown]
# For this, we will use the $\alpha$ value of 0.05 to check against the p-value of 0.021010 to decide if we will accept or reject the $H_0$. As $\alpha$ > p-value, we can conclude that the data is stationary.

# %% [markdown]
# #### (S)ARIMA Parameters

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method1, ax=ax[0], lags = 40)
fig = sm.graphics.tsa.plot_pacf(ds_method1, ax=ax[1], lags = 40)
plt.show()

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(ds_method1, start_p=0, start_q=0,
                           max_p=6, max_q=7, m=12,
                            seasonal=True,
                           d=0 , trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=8.000, BIC=27.695, Fit time=3.651 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=19425.795, BIC=19435.642, Fit time=0.032 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=19305.767, BIC=19325.462, Fit time=0.737 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=19324.241, BIC=19343.935, Fit time=0.711 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=19394.191, BIC=19408.962, Fit time=0.423 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=19380.759, BIC=19405.377, Fit time=7.025 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=19417.094, BIC=19431.865, Fit time=0.442 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=19384.580, BIC=19409.198, Fit time=4.693 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=19374.108, BIC=19403.650, Fit time=12.309 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=19306.650, BIC=19331.268, Fit time=2.453 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=19325.704, BIC=19350.322, Fit time=2.912 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=19278.895, BIC=19308.436, Fit time=5.217 seconds
# Total fit time: 40.635 seconds
# 8.0

# %% [markdown]
# So, the best set of paramters to select is ARIMA(0,0,0)(1,0,1,12). I selected m = 12 to represent the yearly number of months each 'season' runs for.

# %%
model = sm.tsa.statespace.SARIMAX(ds_method1, order=(0,0,0), seasonal_order = (1,0,1,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.529430
#          Iterations: 2
#          Function evaluations: 81

# %%
train = ds_method1.loc['2015-11-29':'2019-03-02']
test = ds_method1.loc['2020-10-14':]
stepwise_model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=None, method=None, order=(0, 0, 0),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(1, 0, 1, 12), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend=None,
#    with_intercept=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method1,
                                order=(0, 0, 0),
                                seasonal_order=(1, 0, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                  SARIMAX Results
# ==================================================================================
# Dep. Variable:                      Steps   No. Observations:                 1016
# Model:             SARIMAX(1, 0, [1], 12)   Log Likelihood               -9543.178
# Date:                    Wed, 18 Nov 2020   AIC                          19092.356
# Time:                            15:43:43   BIC                          19107.088
# Sample:                                 0   HQIC                         19097.954
#                                    - 1016
# Covariance Type:                      opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       1.0096      0.002    637.632      0.000       1.007       1.013
# ma.S.L12      -0.9180      0.014    -65.093      0.000      -0.946      -0.890
# sigma2       1.07e+07    1.5e-10   7.16e+16      0.000    1.07e+07    1.07e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  50.69   Jarque-Bera (JB):               218.25
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.25   Skew:                             0.76
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.42e+31. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %% [markdown]
# #### (S)ARIMA Model Validation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# the 20% point test data is on the specified date below
split_date = '2019-03-02'
data = ds_method1['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(0, 0, 0),
                                seasonal_order=(1, 0, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae1 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse1 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse1 = math.sqrt(mse1)
print(f'Mean Squared Error: {mse1.round(4)}')
print(f'Root Mean Squared Error: {round(rmse1,4)}')
print(f'Mean Absolute Error: {mae1.round(4)}')
# Out:
# Mean Squared Error: 16727395.0477
# Root Mean Squared Error: 4089.9138
# Mean Absolute Error: 3185.3654

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-03-02'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method1['2015':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %% [markdown]
# #### Method 2

# %%
ds_method2.set_index('Date',inplace=True)
ds_method2.head()
# Out:
#                    Steps
# Date
# 2015-11-29   4115.703713
# 2015-11-30   4013.000000
# 2015-12-01   3191.000000
# 2015-12-02   2724.000000
# 2015-12-03  12851.000000

# %%
ds_method2.plot(figsize=(19, 4))
plt.ylabel("Number of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method2, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# Again, data is missing some seasonal data

# %%
test_stationarity(ds_method2)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic              -3.130891
# p-value                          0.024350
# #Lags Used                      17.000000
# Number of Observations Used    998.000000
# Critical Value (1%)             -3.436919
# Critical Value (5%)             -2.864440
# Critical Value (10%)            -2.568314
# dtype: float64

# %% [markdown]
# Data appears to be stationary

# %%
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method2, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method2,ax=ax[1])
plt.show()

# %%
stepwise_model = auto_arima(ds_method2, start_p=0, start_q=0,
                           max_p=5, max_q=6, m=12,
                            seasonal=True,
                           d=0,  trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=19839.729, BIC=19859.423, Fit time=2.520 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=19372.931, BIC=19382.778, Fit time=0.060 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=19250.078, BIC=19269.773, Fit time=0.649 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=19268.590, BIC=19288.285, Fit time=0.676 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=19258.122, BIC=19272.892, Fit time=0.188 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=19250.372, BIC=19274.990, Fit time=3.537 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=19250.989, BIC=19275.607, Fit time=2.811 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=19249.376, BIC=19278.918, Fit time=7.407 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=19326.059, BIC=19350.677, Fit time=4.180 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=19244.036, BIC=19278.502, Fit time=8.369 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=19237.187, BIC=19276.576, Fit time=7.652 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=19229.495, BIC=19278.732, Fit time=13.105 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=19229.450, BIC=19273.763, Fit time=6.466 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=19201.212, BIC=19240.601, Fit time=3.646 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=19202.292, BIC=19236.757, Fit time=3.004 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=19192.044, BIC=19236.356, Fit time=7.712 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=19204.241, BIC=19243.630, Fit time=2.498 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=19183.113, BIC=19232.349, Fit time=6.891 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=19167.786, BIC=19226.870, Fit time=9.571 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=19164.015, BIC=19218.175, Fit time=5.639 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=19166.377, BIC=19225.460, Fit time=9.403 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=19162.316, BIC=19211.552, Fit time=3.557 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=19182.628, BIC=19226.940, Fit time=2.247 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=19165.563, BIC=19219.723, Fit time=4.295 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=19189.112, BIC=19228.501, Fit time=1.634 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=19166.220, BIC=19225.304, Fit time=5.019 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=19167.353, BIC=19221.513, Fit time=8.063 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=19165.029, BIC=19219.189, Fit time=7.249 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=19200.986, BIC=19260.070, Fit time=8.422 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=19175.922, BIC=19220.235, Fit time=3.488 seconds
# Total fit time: 150.030 seconds
# 19162.31593031722

# %% [markdown]
# Best SARIMA is  order=(4,0,4) seasonal_order=(0, 0, 0, 12)

# %%
model = sm.tsa.statespace.SARIMAX(ds_method2, order=(4,0,4), seasonal_order = (0,0,0,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res,  ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res,  ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.426086
#          Iterations: 3
#          Function evaluations: 331

# %%
train = ds_method2.loc['2015-11-29':'2019-03-02']
test = ds_method2.loc['2020-10-14':]
stepwise_model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=None, method=None, order=(4, 0, 4),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 0, 0, 12), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend=None,
#    with_intercept=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method2,
                                order=(4,0,4),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Steps   No. Observations:                 1016
# Model:               SARIMAX(4, 0, 4)   Log Likelihood               -9525.635
# Date:                Wed, 18 Nov 2020   AIC                          19069.269
# Time:                        15:35:06   BIC                          19113.537
# Sample:                             0   HQIC                         19086.085
#                                - 1016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2417      0.215     -1.123      0.262      -0.664       0.180
# ar.L2          0.0337      0.114      0.295      0.768      -0.190       0.258
# ar.L3          0.8422      0.094      8.995      0.000       0.659       1.026
# ar.L4          0.3653      0.173      2.109      0.035       0.026       0.705
# ma.L1          0.4561      0.210      2.174      0.030       0.045       0.867
# ma.L2          0.0359      0.105      0.341      0.733      -0.170       0.242
# ma.L3         -0.7467      0.087     -8.538      0.000      -0.918      -0.575
# ma.L4         -0.4308      0.151     -2.844      0.004      -0.728      -0.134
# sigma2      9.081e+06   2.38e-08   3.81e+14      0.000    9.08e+06    9.08e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               174.04
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.21   Skew:                             0.69
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.61e+30. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# the 20% point test data is on the specified date below
split_date = '2019-03-02'
data = ds_method2['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(4,0,4),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae2 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse2 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse2 = math.sqrt(mse2)
print(f'Mean Squared Error: {mse2.round(4)}')
print(f'Root Mean Squared Error: {round(rmse2,4)}')
print(f'Mean Absolute Error: {mae2.round(4)}')
# Out:
# Mean Squared Error: 15306317.6049
# Root Mean Squared Error: 3912.3289
# Mean Absolute Error: 3035.8685

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-03-02'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method2['2015':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %% [markdown]
# #### Method 3

# %%
ds_method3.set_index('Date',inplace=True)
ds_method3.head()
# Out:
#                    Steps
# Date
# 2015-11-29   4080.573591
# 2015-11-30   3906.552367
# 2015-12-01   2979.000000
# 2015-12-02   2544.000000
# 2015-12-03  12674.000000

# %%
ds_method3.plot(figsize=(19, 4))
plt.ylabel("Number of Steps")
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(ds_method3, model='additive', period = 30)
fig = decomposition.plot()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# Again, our data is missing some seasonal data

# %%
test_stationarity(ds_method3)
# Out:
# Results of Dickey Fuller Test:
# ADF Test Statistic              -4.053433
# p-value                          0.001155
# #Lags Used                      16.000000
# Number of Observations Used    999.000000
# Critical Value (1%)             -3.436913
# Critical Value (5%)             -2.864437
# Critical Value (10%)            -2.568313
# dtype: float64

# %% [markdown]
# P-value is significant, our data is stationary

# %%
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(ds_method3, lags=30, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ds_method3, lags=30, ax=ax[1])
plt.show()

# %%
stepwise_model = auto_arima(ds_method3, start_p=0, start_q=0,
                           max_p=4, max_q=6, m=12,
                            seasonal=True,
                           d=0,  trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=19358.336, BIC=19378.030, Fit time=1.892 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=19070.729, BIC=19080.576, Fit time=0.057 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=19012.607, BIC=19032.301, Fit time=0.649 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=19015.154, BIC=19034.848, Fit time=0.470 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=19020.742, BIC=19035.512, Fit time=0.129 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=19014.522, BIC=19039.140, Fit time=2.037 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=19149.798, BIC=19174.416, Fit time=2.633 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=19012.007, BIC=19041.549, Fit time=7.256 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=19049.776, BIC=19074.395, Fit time=3.670 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=19011.267, BIC=19045.733, Fit time=7.204 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=19006.751, BIC=19046.140, Fit time=8.707 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=19002.945, BIC=19052.182, Fit time=10.810 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=18999.059, BIC=19043.372, Fit time=5.352 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=18986.636, BIC=19026.025, Fit time=2.509 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=18989.716, BIC=19024.181, Fit time=2.208 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=18978.641, BIC=19022.954, Fit time=5.707 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=18983.815, BIC=19023.204, Fit time=2.244 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=18975.773, BIC=19025.009, Fit time=6.391 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=18975.497, BIC=19019.809, Fit time=2.806 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=18974.939, BIC=19024.176, Fit time=5.527 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=18993.872, BIC=19052.955, Fit time=18.064 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=18973.652, BIC=19017.965, Fit time=6.417 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=18985.199, BIC=19024.588, Fit time=1.677 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=18974.104, BIC=19023.340, Fit time=6.556 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=18987.844, BIC=19022.310, Fit time=1.667 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=18965.946, BIC=19020.106, Fit time=6.688 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=19002.035, BIC=19061.118, Fit time=10.427 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=18969.934, BIC=19019.170, Fit time=3.641 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=18969.213, BIC=19028.297, Fit time=22.145 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=18965.536, BIC=19024.619, Fit time=9.265 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=18970.192, BIC=19024.352, Fit time=4.041 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=18966.276, BIC=19020.436, Fit time=9.935 seconds
# Total fit time: 178.835 seconds
# 18965.535914256485

# %% [markdown]
# Best ARIMA order=(4, 0, 5) seasonal_order=(0, 0, 1, 12)

# %%
model = sm.tsa.statespace.SARIMAX(ds_method3, order=(4,0,5), seasonal_order = (0,0,1,12)).fit(max_iter=50, method='powell')
res = model.resid
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, lags=30, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=30, ax=ax[1])
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 9.323487
#          Iterations: 3
#          Function evaluations: 382

# %%
train = ds_method3.loc['2015-11-29':'2019-03-02']
test = ds_method3.loc['2020-10-14':]
stepwise_model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=None, method=None, order=(4, 0, 5),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 0, 1, 12), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend=None,
#    with_intercept=True)

# %%
mod = sm.tsa.statespace.SARIMAX(ds_method3,
                                order=(4,0,5),
                                seasonal_order=(0, 0, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                Steps   No. Observations:                 1016
# Model:             SARIMAX(4, 0, 5)x(0, 0, [1], 12)   Log Likelihood               -9296.352
# Date:                              Wed, 18 Nov 2020   AIC                          18614.704
# Time:                                      15:41:36   BIC                          18668.667
# Sample:                                           0   HQIC                         18635.216
#                                              - 1016
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2037      0.497     -0.410      0.682      -1.178       0.770
# ar.L2          0.4480      0.342      1.310      0.190      -0.222       1.118
# ar.L3          0.2567      0.472      0.544      0.586      -0.668       1.181
# ar.L4          0.4999      0.362      1.380      0.168      -0.210       1.210
# ma.L1          0.3479      0.500      0.696      0.487      -0.632       1.328
# ma.L2         -0.4262      0.382     -1.116      0.265      -1.175       0.323
# ma.L3         -0.2512      0.470     -0.535      0.593      -1.172       0.669
# ma.L4         -0.4688      0.383     -1.223      0.221      -1.220       0.282
# ma.L5         -0.0949      0.048     -1.989      0.047      -0.188      -0.001
# ma.S.L12       0.0400      0.035      1.159      0.246      -0.028       0.108
# sigma2      7.465e+06   3.84e-08   1.94e+14      0.000    7.47e+06    7.47e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               327.05
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.23   Skew:                             0.91
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.87e+30. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# the 20% point test data is on the specified date below
split_date = '2019-03-02'
data = ds_method3['Steps']
train, test = data[:split_date], data[split_date:]
test_len = len(test)
model = sm.tsa.statespace.SARIMAX(train,
                                order=(4,0,5),
                                seasonal_order=(0,0,1,12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
model_fit = model.fit(disp=-1)
prediction = model_fit.forecast(test_len)

# %%
pred_df = pd.DataFrame(np.array(prediction), index= test.index)
mae3 = mean_absolute_error(test.dropna(), pred_df.dropna())
mse3 = mean_squared_error(test.dropna(), pred_df.dropna())
rmse3 = math.sqrt(mse3)
print(f'Mean Squared Error: {mse3.round(4)}')
print(f'Root Mean Squared Error: {round(rmse3,4)}')
print(f'Mean Absolute Error: {mae3.round(4)}')
# Out:
# Mean Squared Error: 11258177.7945
# Root Mean Squared Error: 3355.3208
# Mean Absolute Error: 2563.4907

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-03-02'), dynamic=False)
pred_ci = pred.conf_int()
#Potentially change the start date so its more zoomed in? 
ax = ds_method3['2015':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Steps')
plt.legend()
plt.show()

# %%
models = pd.DataFrame({
    'Method': ['Method 1', 'Method 2', 'Method 3'],
    'MSE': [round(mse1, 4), round(mse2, 4), round(mse3,4)],
    'RMSE': [round(rmse1,4 ), round(rmse2, 4), round(rmse3,4)],
    'MAE': [round(mae1, 4), round(mae2, 4), round(mae3,4)]})
models
# Out:
#      Method           MSE       RMSE        MAE
# 0  Method 1  1.672740e+07  4089.9138  3185.3654
# 1  Method 2  1.530632e+07  3912.3289  3035.8685
# 2  Method 3  1.125818e+07  3355.3208  2563.4907

# %% [markdown]
# Based on the above predictions, we can observe that **Method 1** and **Method 2** have a very similar prediction with **Method 1** performing the worst. However, the **RMSE** value of **Model 3** is lower, therefore, we can conclude that the **Method 3** performs the best here.
